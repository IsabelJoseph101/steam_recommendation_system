# %% [markdown]
# # STEAM VIDEO GAMES RECOMMENDATION SYSTEM

# %% [markdown]
# # BUSINESS PROBLEM

# %% [markdown]
# For this project i will be creating a content and collaborative based recommendation model that provides video game recommendations to steam users. This project will utlize Steam's API, SteamSpy's API along with data sets sourced from kaggle in order to create a recommendation system.
# <br><br>
# The aim of this project is to improve steam's current recommendation system to provide users with much more accurate recommendations.

# %% [markdown]
# ### Importing necessary packages

# %%
# importing necessary packages
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import json
import requests
from bs4 import BeautifulSoup

from sklearn.preprocessing import StandardScaler 
from sklearn import preprocessing

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# # Obtaining the API key

# %%
# function that obtains api key from folder
def get_keys(path):
    ''' this function obtains the api key'''
    with open(path) as f:
        return json.load(f)

# %%
# getting the api key
keys = get_keys("/Users/Visitor/Documents/Flatiron/capstone_project/.secret/steam_api.json")

# %%
# getting and assigning the api key to a variable
api_key = keys['api_key']

# %% [markdown]
# # Generating requests from Steam's API

# %% [markdown]
# From Steam's api the following data will be used:
# <li>GetPlayerSummaries
# <li>GetUserStatsForGame
# <li>GetRecentlyPlayedGames
# <li>GetOwnedGames
# <li>GetFriendList
# <li>GetAppList

# %% [markdown]
# ### Player summaries (GetPlayerSummaries)

# %%
# getting requests from the api for the player summaries
resp = requests.get("http://api.steampowered.com/ISteamUser/GetPlayerSummaries/v0002/?key=B8DD767E6A0BF4F61B05D6E5483C29A9&steamids=76561197960435530")

# %%
# checking if the request was sucessful
resp.status_code == requests.codes.ok
# Out:
# True

# %%
#filtering the data
resp.json()['response']['players']
# Out:
# [{'steamid': '76561197960435530',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Robin',
#   'profileurl': 'https://steamcommunity.com/id/robinwalker/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/f1/f1dd60a188883caf82d0cbfccfe6aba0af1732d4.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/f1/f1dd60a188883caf82d0cbfccfe6aba0af1732d4_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/f1/f1dd60a188883caf82d0cbfccfe6aba0af1732d4_full.jpg',
#   'avatarhash': 'f1dd60a188883caf82d0cbfccfe6aba0af1732d4',
#   'personastate': 0,
#   'realname': 'Robin Walker',
#   'primaryclanid': '103582791429521412',
#   'timecreated': 1063407589,
#   'personastateflags': 0,
#   'loccountrycode': 'US',
#   'locstatecode': 'WA',
#   'loccityid': 3961}]

# %%
# creating a data frame using the obtained information
df = pd.DataFrame.from_dict(resp.json()['response']['players'])

# %%
# displaying the data frame
df.head()
# Out:
#              steamid  communityvisibilitystate  profilestate personaname  \
# 0  76561197960435530                         3             1       Robin
#
#                                    profileurl                                             avatar  \
# 0  https://steamcommunity.com/id/robinwalker/  https://steamcdn-a.akamaihd.net/steamcommunity...
#
#                                         avatarmedium  \
# 0  https://steamcdn-a.akamaihd.net/steamcommunity...
#
#                                           avatarfull                                avatarhash  \
# 0  https://steamcdn-a.akamaihd.net/steamcommunity...  f1dd60a188883caf82d0cbfccfe6aba0af1732d4
#
#    personastate      realname       primaryclanid  timecreated  personastateflags loccountrycode  \
# 0             0  Robin Walker  103582791429521412   1063407589                  0             US
#
#   locstatecode  loccityid
# 0           WA       3961

# %% [markdown]
# ### Friend's list (GetFriendList)

# %%
# getting requests from the api for users friend lists
resp = requests.get("http://api.steampowered.com/ISteamUser/GetFriendList/v0001/?key=B8DD767E6A0BF4F61B05D6E5483C29A9&steamid=76561197960435530&relationship=friend")

# %%
# checking if the request was sucessful
resp.status_code == requests.codes.ok
# Out:
# True

# %%
# filtering the data
# resp.json()['friendslist']['friends']

# %%
# creating a data frame from the obtained data
df = pd.DataFrame.from_dict(resp.json()['friendslist']['friends'])

# %%
# displaying the newly created data frame
df.head()
# Out:
#              steamid relationship  friend_since
# 0  76561197960265731       friend             0
# 1  76561197960265738       friend             0
# 2  76561197960265740       friend             0
# 3  76561197960265744       friend    1585508613
# 4  76561197960265747       friend             0

# %% [markdown]
# ### List of all games (GetAppList)

# %%
# obtaining requests from the api to get a list of steam games
resp = requests.get("https://api.steampowered.com/ISteamApps/GetAppList/v2/")

# %%
# checking if the request was sucessful
resp.status_code == requests.codes.ok
# Out:
# True

# %%
#filtering the data
#resp.json()['applist']['apps']

# %%
# creating a data frame with the obtained data
df_games = pd.DataFrame.from_dict(resp.json()['applist']['apps'])

# %%
# displaying the data frame
df_games.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Generating requests from SteamSpy

# %% [markdown]
# ### Using steamspy to request steam's game information

# %%
# requesting all game data from steamspy
resp = requests.get("http://steamspy.com/api.php?request=all")

# %%
# converting the request to json format
dic_app_user = resp.json()

# %%
# obtaining the keys of the dictionary
lst_app_id = dic_app_user.keys()

# %%
# checking length
len(dic_app_user)
# Out:
# 35855

# %%
# checking if the request was sucessful
resp.status_code == requests.codes.ok
# Out:
# True

# %%
# filtering the data
# resp.json()

# %%
# converting the dictionary to a data frame
df = pd.DataFrame.from_dict(resp.json())

# %%
# displaying the data frame
df
# Out:
#                                         570                               730  \
# appid                                   570                               730
# name                                 Dota 2  Counter-Strike: Global Offensive
# developer                             Valve  Valve, Hidden Path Entertainment
# publisher                             Valve                             Valve
# score_rank
# positive                            1096061                           3828150
# negative                             194043                            532417
# userscore                                 0                                 0
# owners           100,000,000 .. 200,000,000        100,000,000 .. 200,000,000
# average_forever                       31602                             27524
# average_2weeks                         1707                              1201
# median_forever                         1211                              8399
# median_2weeks                           876                               470
# price                                     0                                 0
# initialprice                              0                                 0
# discount                                  0                                 0
#
#                                         578080                       440  \
# appid                                   578080                       440
# name             PLAYERUNKNOWN'S BATTLEGROUNDS           Team Fortress 2
# developer                     PUBG Corporation                     Valve
# publisher                     PUBG Corporation                     Valve
# score_rank
# positive                                780582                    626993
# negative                                663880                     39149
# userscore                                    0                         0
# owners                20,000,000 .. 50,000,000  20,000,000 .. 50,000,000
# average_forever                          23253                      8201
# average_2weeks                             663                      1206
# median_forever                           10926                       424
# median_2weeks                              210                       261
# price                                     2999                         0
# initialprice                              2999                         0
# discount                                     0                         0
#
#                                    304930                    230410                    271590  \
# appid                              304930                    230410                    271590
# name                             Unturned                  Warframe        Grand Theft Auto V
# developer           Smartly Dressed Games          Digital Extremes            Rockstar North
# publisher           Smartly Dressed Games          Digital Extremes            Rockstar Games
# score_rank
# positive                           348990                    327447                    686046
# negative                            34793                     32630                    175493
# userscore                               0                         0                         0
# owners           20,000,000 .. 50,000,000  20,000,000 .. 50,000,000  20,000,000 .. 50,000,000
# average_forever                      3158                      7605                     11314
# average_2weeks                        969                      1563                       879
# median_forever                        326                       417                      5034
# median_2weeks                         612                       566                       297
# price                                   0                         0                      2999
# initialprice                            0                         0                      2999
# discount                                0                         0                         0
#
#                                          359550                    291550  \
# appid                                    359550                    291550
# name             Tom Clancy's Rainbow Six Siege                Brawlhalla
# developer                      Ubisoft Montreal        Blue Mammoth Games
# publisher                               Ubisoft                   Ubisoft
# score_rank
# positive                                 597298                    128060
# negative                                  84303                     22734
# userscore                                     0                         0
# owners                 20,000,000 .. 50,000,000  20,000,000 .. 50,000,000
# average_forever                           12352                      1441
# average_2weeks                              966                       184
# median_forever                             3293                       183
# median_2weeks                               368                        71
# price                                      1999                         0
# initialprice                               1999                         0
# discount                                      0                         0
#
#                                       550                    105600                      4000  \
# appid                                 550                    105600                      4000
# name                        Left 4 Dead 2                  Terraria               Garry's Mod
# developer                           Valve                  Re-Logic         Facepunch Studios
# publisher                           Valve                  Re-Logic                     Valve
# score_rank
# positive                           344542                    488434                    535259
# negative                            10420                     10776                     20365
# userscore                               0                         0                         0
# owners           20,000,000 .. 50,000,000  20,000,000 .. 50,000,000  10,000,000 .. 20,000,000
# average_forever                      2375                      6118                      8400
# average_2weeks                        246                       569                       509
# median_forever                        585                      1764                      1366
# median_2weeks                         156                       214                       101
# price                                 999                       999                       999
# initialprice                          999                       999                       999
# discount                                0                         0                         0
#
#                                        10                       340                    272060  \
# appid                                  10                       340                    272060
# name                       Counter-Strike   Half-Life 2: Lost Coast                    Serena
# developer                           Valve                     Valve                  Senscape
# publisher                           Valve                     Valve                  Senscape
# score_rank
# positive                           154127                      6874                      4735
# negative                             4015                      1109                      1415
# userscore                               0                         0                         0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                      7037                       163                       462
# average_2weeks                        300                        22                      3629
# median_forever                        157                        29                        14
# median_2weeks                         427                        22                      3629
# price                                 999                         0                         0
# initialprice                          999                         0                         0
# discount                                0                         0                         0
#
#                                    444090                       240                    236390  \
# appid                              444090                       240                    236390
# name                             Paladins    Counter-Strike: Source               War Thunder
# developer                 Evil Mojo Games                     Valve      Gaijin Entertainment
# publisher                  Hi-Rez Studios                     Valve   Gaijin Distribution KFT
# score_rank
# positive                           227458                    100800                    126394
# negative                            38779                      4209                     30458
# userscore                               0                         0                         0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                      2502                      7229                      3353
# average_2weeks                        652                       132                       865
# median_forever                        456                       499                       347
# median_2weeks                         548                        60                       759
# price                                   0                       999                         0
# initialprice                            0                       999                         0
# discount                                0                         0                         0
#
#                                    238960                           218620  \
# appid                              238960                           218620
# name                        Path of Exile                         PAYDAY 2
# developer             Grinding Gear Games  OVERKILL - a Starbreeze Studio.
# publisher             Grinding Gear Games         Starbreeze Publishing AB
# score_rank
# positive                           122832                           376070
# negative                             8873                            58191
# userscore                               0                                0
# owners           10,000,000 .. 20,000,000         10,000,000 .. 20,000,000
# average_forever                      6631                             4425
# average_2weeks                         19                             1061
# median_forever                        421                              753
# median_2weeks                          25                              532
# price                                   0                              999
# initialprice                            0                              999
# discount                                0                                0
#
#                                                         49520                    227940  \
# appid                                                   49520                    227940
# name                                            Borderlands 2         Heroes & Generals
# developer        Gearbox Software, Aspyr (Mac), Aspyr (Linux)                 RETO MOTO
# publisher                      2K, Aspyr (Mac), Aspyr (Linux)                 RETO MOTO
# score_rank
# positive                                               211378                     79706
# negative                                                15118                     38877
# userscore                                                   0                         0
# owners                               10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                                          3470                       846
# average_2weeks                                            139                       199
# median_forever                                            909                        85
# median_2weeks                                             198                       215
# price                                                    1999                         0
# initialprice                                             1999                         0
# discount                                                    0                         0
#
#                                                        275390                   1085660  \
# appid                                                  275390                   1085660
# name             Guacamelee! Super Turbo Championship Edition                 Destiny 2
# developer                                    DrinkBox Studios                    Bungie
# publisher                                    DrinkBox Studios                    Bungie
# score_rank
# positive                                                 4420                    203023
# negative                                                  368                     29922
# userscore                                                   0                         0
# owners                               10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                                           268                      4180
# average_2weeks                                            168                       999
# median_forever                                             54                       386
# median_2weeks                                             168                       449
# price                                                    1499                         0
# initialprice                                             1499                         0
# discount                                                    0                         0
#
#                                    301520                    252950                    291480  \
# appid                              301520                    252950                    291480
# name                            Robocraft             Rocket League                   Warface
# developer                         Freejam               Psyonix LLC                  MY.GAMES
# publisher                         Freejam               Psyonix LLC                  MY.GAMES
# score_rank
# positive                            84103                    380129                     39579
# negative                            32044                     39454                     17322
# userscore                               0                         0                         0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                      1391                     11281                       776
# average_2weeks                         32                       512                       267
# median_forever                        301                      1988                       128
# median_2weeks                          42                       228                       401
# price                                   0                      1999                         0
# initialprice                            0                      1999                         0
# discount                                0                         0                         0
#
#                                       220                    252490                           360  \
# appid                                 220                    252490                           360
# name                          Half-Life 2                      Rust  Half-Life Deathmatch: Source
# developer                           Valve         Facepunch Studios                         Valve
# publisher                           Valve         Facepunch Studios                         Valve
# score_rank
# positive                            97750                    366994                          1786
# negative                             2896                     72638                           566
# userscore                               0                         0                             0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000      10,000,000 .. 20,000,000
# average_forever                       674                     16775                           388
# average_2weeks                        282                      2323                             0
# median_forever                        328                      3277                            20
# median_2weeks                         511                      1309                             0
# price                                 999                      3999                           999
# initialprice                          999                      3999                           999
# discount                                0                         0                             0
#
#                                    304050                       620                    433850  \
# appid                              304050                       620                    433850
# name                                Trove                  Portal 2          Z1 Battle Royale
# developer                    Trion Worlds                     Valve     Daybreak Game Company
# publisher                    Trion Worlds                     Valve     Daybreak Game Company
# score_rank
# positive                            58338                    190881                    114919
# negative                            14976                      2426                     93843
# userscore                               0                         0                         0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                      1698                       992                      3764
# average_2weeks                        237                       205                     10386
# median_forever                        212                       503                       184
# median_2weeks                         268                       147                     10386
# price                                   0                       999                         0
# initialprice                            0                       999                         0
# discount                                0                         0                         0
#
#                                    550650                    386360                    96000  \
# appid                              550650                    386360                    96000
# name                          Black Squad                     SMITE      The Tiny Bang Story
# developer                       NS STUDIO         Titan Forge Games            Colibri Games
# publisher                       NS STUDIO            Hi-Rez Studios            Colibri Games
# score_rank
# positive                            52308                     52253                     4561
# negative                            15126                     12448                      650
# userscore                               0                         0                        0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  5,000,000 .. 10,000,000
# average_forever                      1245                      2134                      300
# average_2weeks                         78                       983                      225
# median_forever                         70                       132                      308
# median_2weeks                          86                      1409                      225
# price                                   0                         0                      499
# initialprice                            0                         0                      499
# discount                                0                         0                        0
#
#                                    44350                                       8930  \
# appid                              44350                                       8930
# name                              GRID 2                 Sid Meier's Civilization V
# developer             Codemasters Racing  Firaxis Games, Aspyr (Mac), Aspyr (Linux)
# publisher                    Codemasters             2K, Aspyr (Mac), Aspyr (Linux)
# score_rank
# positive                           20079                                     154764
# negative                            4229                                       6267
# userscore                              0                                          0
# owners           5,000,000 .. 10,000,000                    5,000,000 .. 10,000,000
# average_forever                      556                                       6648
# average_2weeks                       196                                        554
# median_forever                       116                                       2009
# median_2weeks                        290                                        855
# price                                  0                                       2999
# initialprice                           0                                       2999
# discount                               0                                          0
#
#                                        72850                   417910  \
# appid                                  72850                   417910
# name             The Elder Scrolls V: Skyrim   Street Warriors Online
# developer              Bethesda Game Studios      Crazy Rocks Studios
# publisher                 Bethesda Softworks      Crazy Rocks Studios
# score_rank
# positive                              266483                      989
# negative                               15306                      728
# userscore                                  0                        0
# owners               5,000,000 .. 10,000,000  5,000,000 .. 10,000,000
# average_forever                         7515                       88
# average_2weeks                           285                        0
# median_forever                          3514                      101
# median_2weeks                            188                        0
# price                                   1999                      199
# initialprice                            1999                      199
# discount                                   0                        0
#
#                                              80                      381210  \
# appid                                        80                      381210
# name             Counter-Strike: Condition Zero            Dead by Daylight
# developer                                 Valve  Behaviour Interactive Inc.
# publisher                                 Valve  Behaviour Interactive Inc.
# score_rank
# positive                                  15082                      246984
# negative                                   1592                       61060
# userscore                                     0                           0
# owners                  5,000,000 .. 10,000,000     5,000,000 .. 10,000,000
# average_forever                            1633                        8032
# average_2weeks                                0                        1155
# median_forever                               39                        1097
# median_2weeks                                 0                         811
# price                                       999                        1999
# initialprice                                999                        1999
# discount                                      0                           0
#
#                                   431960                   582010                   218230  \
# appid                             431960                   582010                   218230
# name                    Wallpaper Engine    MONSTER HUNTER: WORLD             PlanetSide 2
# developer          Wallpaper Engine Team         CAPCOM Co., Ltd.       Rogue Planet Games
# publisher          Wallpaper Engine Team         CAPCOM Co., Ltd.    Daybreak Game Company
# score_rank
# positive                          170926                   199396                    44690
# negative                            3107                    43651                     9112
# userscore                              0                        0                        0
# owners           5,000,000 .. 10,000,000  5,000,000 .. 10,000,000  5,000,000 .. 10,000,000
# average_forever                     2175                     9286                     1610
# average_2weeks                       235                     1032                       12
# median_forever                       497                     4497                      160
# median_2weeks                         20                      486                       19
# price                                399                     2999                        0
# initialprice                         399                     2999                        0
# discount                               0                        0                        0
#
#                                    292030                       70                      320  \
# appid                              292030                       70                      320
# name             The Witcher 3: Wild Hunt                Half-Life  Half-Life 2: Deathmatch
# developer                  CD PROJEKT RED                    Valve                    Valve
# publisher                  CD PROJEKT RED                    Valve                    Valve
# score_rank
# positive                           363438                    44922                     7442
# negative                             7010                     1682                      871
# userscore                               0                        0                        0
# owners            5,000,000 .. 10,000,000  5,000,000 .. 10,000,000  5,000,000 .. 10,000,000
# average_forever                      4710                      786                      473
# average_2weeks                       1051                       12                        0
# median_forever                       1340                      179                       49
# median_2weeks                         494                       24                        0
# price                                1199                      999                      499
# initialprice                         3999                      999                      499
# discount                               70                        0                        0
#
#                                   755790                   370910  ...           723210  \
# appid                             755790                   370910  ...           723210
# name                     Ring of Elysium               Kathy Rain  ...  Mind Sweeper VR
# developer                  Aurora Studio           Clifftop Games  ...    Chad R. Banks
# publisher            TCH Scarlet Limited                 Raw Fury  ...    Chad R. Banks
# score_rank                                                         ...
# positive                           66975                     2428  ...                0
# negative                           21062                      192  ...                0
# userscore                              0                        0  ...                0
# owners           5,000,000 .. 10,000,000  5,000,000 .. 10,000,000  ...      0 .. 20,000
# average_forever                      654                     1502  ...                0
# average_2weeks                        26                      273  ...                0
# median_forever                       129                      268  ...                0
# median_2weeks                         26                      273  ...                0
# price                                  0                     1499  ...              199
# initialprice                           0                     1499  ...              199
# discount                               0                        0  ...                0
#
#                                    439400           702620       709390         72530  \
# appid                              439400           702620       709390         72530
# name             Legends of Callasia Demo  Wrecking Towers    Chewbrick  Arcadia Beta
# developer                                        Mindtrick      Decabry
# publisher                                        Mindtrick      Decabry
# score_rank
# positive                                0                0            0             0
# negative                                0                0            0             0
# userscore                               0                0            0             0
# owners                        0 .. 20,000      0 .. 20,000  0 .. 20,000   0 .. 20,000
# average_forever                         0                0            0             0
# average_2weeks                          0                0            0             0
# median_forever                          0                0            0             0
# median_2weeks                           0                0            0             0
# price                                None                0            0             0
# initialprice                         None                0            0             0
# discount                             None                0            0             0
#
#                           794240       809640        804910                        804540  \
# appid                     794240       809640        804910                        804540
# name                      Spinch        尺子和橡皮   Mine Seeker  Greedy Developer's Cash Grab
# developer        Queen Bee Games       XIAOMU  Jason Crosby              Greedy Developer
# publisher          Akupara Games       XIAOMU  Jason Crosby              Greedy Publisher
# score_rank
# positive                       0            0             0                             0
# negative                       0            0             0                             0
# userscore                      0            0             0                             0
# owners               0 .. 20,000  0 .. 20,000   0 .. 20,000                   0 .. 20,000
# average_forever                0            0             0                             0
# average_2weeks                 0            0             0                             0
# median_forever                 0            0             0                             0
# median_2weeks                  0            0             0                             0
# price                          0            0           799                             0
# initialprice                   0            0           799                             0
# discount                       0            0             0                             0
#
#                                   865810               599490                       743920  \
# appid                             865810               599490                       743920
# name             Waifu Fight Dango Style        Bounty Killer  Choo-Choo! The Train Rides!
# developer             Enso Entertainment   Galaxy Game Studio                     SE Games
# publisher             Enso Entertainment  Galaxy Game Studio                      SeStudio
# score_rank
# positive                               0                    0                            0
# negative                               0                    0                            0
# userscore                              0                    0                            0
# owners                       0 .. 20,000          0 .. 20,000                  0 .. 20,000
# average_forever                        0                    0                            0
# average_2weeks                         0                    0                            0
# median_forever                         0                    0                            0
# median_2weeks                          0                    0                            0
# price                                  0                    0                            0
# initialprice                           0                    0                            0
# discount                               0                    0                            0
#
#                          785790                    611820           652730           789710  \
# appid                    785790                    611820           652730           789710
# name             WHAT THE GOLF?  Xenosis: Alien Infection     Z-Aftershock  BoyAndLabyrinth
# developer               Triband          NerdRage Studios  Mango Tree Game          WBTgame
# publisher               Triband          NerdRage Studios  Mango Tree Game          WBTgame
# score_rank
# positive                      0                         0                0                0
# negative                      0                         0                0                0
# userscore                     0                         0                0                0
# owners              0 .. 20,000               0 .. 20,000      0 .. 20,000      0 .. 20,000
# average_forever               0                         0                0                0
# average_2weeks                0                         0                0                0
# median_forever                0                         0                0                0
# median_2weeks                 0                         0                0                0
# price                         0                         0                0              499
# initialprice                  0                         0                0              499
# discount                      0                         0                0                0
#
#                        729290              705000         541310                 736240  \
# appid                  729290              705000         541310                 736240
# name             Hidden Cubes          OctorSpace      Tiny Thor  The Revolt: Awakening
# developer          NixieCraft  DrinkingNails, LLC  Asylum Square        Siberius Studio
# publisher          NixieCraft  DrinkingNails, LLC  Asylum Square        Siberius Studio
# score_rank
# positive                    0                   0              0                      0
# negative                    0                   0              0                      0
# userscore                   0                   0              0                      0
# owners            0 .. 20,000         0 .. 20,000    0 .. 20,000            0 .. 20,000
# average_forever             0                   0              0                      0
# average_2weeks              0                   0              0                      0
# median_forever              0                   0              0                      0
# median_2weeks               0                   0              0                      0
# price                     599                   0              0                      0
# initialprice              599                   0              0                      0
# discount                    0                   0              0                      0
#
#                                     750200            751270                   761720  \
# appid                               750200            751270                   761720
# name             AWAY: The Survival Series         BioEntity  Can you eat by yourself
# developer                   Breaking Walls  Sneaky Party LLC         Independent team
# publisher                   Breaking Walls  Sneaky Party LLC         Independent team
# score_rank
# positive                                 0                 0                        0
# negative                                 0                 0                        0
# userscore                                0                 0                        0
# owners                         0 .. 20,000       0 .. 20,000              0 .. 20,000
# average_forever                          0                 0                        0
# average_2weeks                           0                 0                        0
# median_forever                           0                 0                        0
# median_2weeks                            0                 0                        0
# price                                    0                 0                        0
# initialprice                             0                 0                        0
# discount                                 0                 0                        0
#
#                         723360       593150         201930            675330       778140  \
# appid                   723360       593150         201930            675330       778140
# name                   Asunder      Ooblets  Jamestown IGF       Space Crawl      BRIKS 2
# developer        Dawson Frakes  Glumberland                 Hyperfine Studio      Smobile
# publisher        Dawson Frakes  Glumberland                 Hyperfine Studio      Smobile
# score_rank
# positive                     0            0              0                 0            0
# negative                     0            0              0                 0            0
# userscore                    0            0              0                 0            0
# owners             0 .. 20,000  0 .. 20,000    0 .. 20,000       0 .. 20,000  0 .. 20,000
# average_forever              0            0              0                 0            0
# average_2weeks               0            0              0                 0            0
# median_forever               0            0              0                 0            0
# median_2weeks                0            0              0                 0            0
# price                        0            0              0                 0          999
# initialprice                 0            0              0                 0          999
# discount                     0            0              0                 0            0
#
#                       591020         646240       858730  \
# appid                 591020         646240       858730
# name                      山贼  Bacon May Die   Yoke Light
# developer             Tushuo        SnoutUp    Kotoshiro
# publisher             Tushuo        SnoutUp    Kotoshiro
# score_rank
# positive                   0              0            0
# negative                   0              0            0
# userscore                  0              0            0
# owners           0 .. 20,000    0 .. 20,000  0 .. 20,000
# average_forever            0              0            0
# average_2weeks             0              0            0
# median_forever             0              0            0
# median_2weeks              0              0            0
# price                      0              0           99
# initialprice               0              0           99
# discount                   0              0            0
#
#                                                             651490          654200       706550  \
# appid                                                       651490          654200       706550
# name                                                No Longer Home   Seven: Reboot         Kaya
# developer        Humble Grove, Hana Lee, Cel Davison, Adrienne ...  CakeEaterGames        KirUn
# publisher                                             Humble Grove  CakeEaterGames        KirUn
# score_rank
# positive                                                         0               0            0
# negative                                                         0               0            0
# userscore                                                        0               0            0
# owners                                                 0 .. 20,000     0 .. 20,000  0 .. 20,000
# average_forever                                                  0               0            0
# average_2weeks                                                   0               0            0
# median_forever                                                   0               0            0
# median_2weeks                                                    0               0            0
# price                                                            0               0            0
# initialprice                                                     0               0            0
# discount                                                         0               0            0
#
#                                          587030                                 46470  \
# appid                                    587030                                 46470
# name             Bunker Busters Steamworks Test  Grotesque Tactics: Evil Heroes - Dev
# developer
# publisher
# score_rank
# positive                                      0                                     0
# negative                                      0                                     0
# userscore                                     0                                     0
# owners                              0 .. 20,000                           0 .. 20,000
# average_forever                               0                                     0
# average_2weeks                                0                                     0
# median_forever                                0                                     0
# median_2weeks                                 0                                     0
# price                                      None                                     0
# initialprice                               None                                     0
# discount                                   None                                     0
#
#                              852        701360               18310        17760  \
# appid                        852        701360               18310        17760
# name             ValveTestApp852  Fate Crawler  Spectraball - Demo
# developer                           MixerGames
# publisher                           MixerGames
# score_rank
# positive                       0             0                   0            0
# negative                       0             0                   0            0
# userscore                      0             0                   0            0
# owners               0 .. 20,000   0 .. 20,000         0 .. 20,000  0 .. 20,000
# average_forever                0             0                   0            0
# average_2weeks                 0             0                   0            0
# median_forever                 0             0                   0            0
# median_2weeks                  0             0                   0            0
# price                          0             0                   0            0
# initialprice                   0             0                   0            0
# discount                       0             0                   0            0
#
#                                    497960               721460               859120  \
# appid                              497960               721460               859120
# name             Legends of Callasia Demo  Xeno Time Inception  That Tiny Spaceship
# developer                                      Xeno Gaming LLC  We Make Small Games
# publisher                                      Xeno Gaming LLC  We Make Small Games
# score_rank
# positive                                0                    0                    0
# negative                                0                    0                    0
# userscore                               0                    0                    0
# owners                        0 .. 20,000          0 .. 20,000          0 .. 20,000
# average_forever                         0                    0                    0
# average_2weeks                          0                    0                    0
# median_forever                          0                    0                    0
# median_2weeks                           0                    0                    0
# price                                None                    0                    0
# initialprice                         None                    0                    0
# discount                             None                    0                    0
#
#                          512720               848400            643930                    553140  \
# appid                    512720               848400            643930                    553140
# name             Velocidevorium        Simian Rising  拯救大魔王3 Falsemen3              Green Mirror
# developer          Really Slick  All Caps Industries           吃了就睡工作室  Bad2theBone, Glumpy Fish
# publisher          Really Slick  All Caps Industries           吃了就睡工作室               Glumpy Fish
# score_rank
# positive                      0                    0                 0                         0
# negative                      0                    0                 0                         0
# userscore                     0                    0                 0                         0
# owners              0 .. 20,000          0 .. 20,000       0 .. 20,000               0 .. 20,000
# average_forever               0                    0                 0                         0
# average_2weeks                0                    0                 0                         0
# median_forever                0                    0                 0                         0
# median_2weeks                 0                    0                 0                         0
# price                         0                 1299                 0                         0
# initialprice                  0                 1299                 0                         0
# discount                      0                    0                 0                         0
#
#                         781150                                  874630             1031290
# appid                   781150                                  874630             1031290
# name                 Gene Rain  M.A.D. Cliff - All Quiet On The Bridge       Grove flowers
# developer        Deeli network                            Flying Whale  Artepi Corporation
# publisher        Deeli network                            Flying Whale  Artepi Corporation
# score_rank
# positive                     0                                       0                   6
# negative                     0                                       0                   3
# userscore                    0                                       0                   0
# owners             0 .. 20,000                             0 .. 20,000         0 .. 20,000
# average_forever              0                                       0                   0
# average_2weeks               0                                       0                   0
# median_forever               0                                       0                   0
# median_2weeks                0                                       0                   0
# price                        0                                     599                 599
# initialprice                 0                                     599                 599
# discount                     0                                       0                   0
#
# [16 rows x 35855 columns]

# %%
# checking the shape 
df.shape
# Out:
# (16, 35855)

# %%
# transposing the data frame to convert the columns into rows
df = df.T

# %%
# checking the updated data frame
df.head()
# Out:
#          appid                              name                         developer  \
# 570        570                            Dota 2                             Valve
# 730        730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 578080  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 440        440                   Team Fortress 2                             Valve
# 304930  304930                          Unturned             Smartly Dressed Games
#
#                     publisher score_rank positive negative userscore                      owners  \
# 570                     Valve             1096061   194043         0  100,000,000 .. 200,000,000
# 730                     Valve             3828150   532417         0  100,000,000 .. 200,000,000
# 578080       PUBG Corporation              780582   663880         0    20,000,000 .. 50,000,000
# 440                     Valve              626993    39149         0    20,000,000 .. 50,000,000
# 304930  Smartly Dressed Games              348990    34793         0    20,000,000 .. 50,000,000
#
#        average_forever average_2weeks median_forever median_2weeks price initialprice discount
# 570              31602           1707           1211           876     0            0        0
# 730              27524           1201           8399           470     0            0        0
# 578080           23253            663          10926           210  2999         2999        0
# 440               8201           1206            424           261     0            0        0
# 304930            3158            969            326           612     0            0        0

# %%
# checking shape
df.shape
# Out:
# (35855, 16)

# %%
# checking for any null values in this data set
df.isnull().any()
# Out:
# appid              False
# name               False
# developer          False
# publisher          False
# score_rank         False
# positive           False
# negative           False
# userscore          False
# owners             False
# average_forever    False
# average_2weeks     False
# median_forever     False
# median_2weeks      False
# price               True
# initialprice        True
# discount            True
# dtype: bool

# %%
# reseting index so that it doesnt show the appid twice
df.reset_index(drop=True, inplace=True)

# %%
# displaying the data frame to check the changes
df.head()
# Out:
#     appid                              name                         developer  \
# 0     570                            Dota 2                             Valve
# 1     730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 3     440                   Team Fortress 2                             Valve
# 4  304930                          Unturned             Smartly Dressed Games
#
#                publisher score_rank positive negative userscore                      owners  \
# 0                  Valve             1096061   194043         0  100,000,000 .. 200,000,000
# 1                  Valve             3828150   532417         0  100,000,000 .. 200,000,000
# 2       PUBG Corporation              780582   663880         0    20,000,000 .. 50,000,000
# 3                  Valve              626993    39149         0    20,000,000 .. 50,000,000
# 4  Smartly Dressed Games              348990    34793         0    20,000,000 .. 50,000,000
#
#   average_forever average_2weeks median_forever median_2weeks price initialprice discount
# 0           31602           1707           1211           876     0            0        0
# 1           27524           1201           8399           470     0            0        0
# 2           23253            663          10926           210  2999         2999        0
# 3            8201           1206            424           261     0            0        0
# 4            3158            969            326           612     0            0        0

# %% [markdown]
# # Importing data frames

# %% [markdown]
# ### Data frame with games information

# %%
# inital data frame with the scraped data from steamspy
df.head()
# Out:
#     appid                              name                         developer  \
# 0     570                            Dota 2                             Valve
# 1     730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 3     440                   Team Fortress 2                             Valve
# 4  304930                          Unturned             Smartly Dressed Games
#
#                publisher score_rank positive negative userscore                      owners  \
# 0                  Valve             1096061   194043         0  100,000,000 .. 200,000,000
# 1                  Valve             3828150   532417         0  100,000,000 .. 200,000,000
# 2       PUBG Corporation              780582   663880         0    20,000,000 .. 50,000,000
# 3                  Valve              626993    39149         0    20,000,000 .. 50,000,000
# 4  Smartly Dressed Games              348990    34793         0    20,000,000 .. 50,000,000
#
#   average_forever average_2weeks median_forever median_2weeks price initialprice discount
# 0           31602           1707           1211           876     0            0        0
# 1           27524           1201           8399           470     0            0        0
# 2           23253            663          10926           210  2999         2999        0
# 3            8201           1206            424           261     0            0        0
# 4            3158            969            326           612     0            0        0

# %% [markdown]
# ### Data frame with player purchase/play information

# %% [markdown]
# this data set was sourced from kaggle: https://www.kaggle.com/tamber/steam-video-games

# %%
# player purchase/play details
df_2 = pd.read_csv('steam-200k.csv')
df_2.head()
# Out:
#    151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 0  151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 1  151603712                   Fallout 4  purchase    1.0  0
# 2  151603712                   Fallout 4      play   87.0  0
# 3  151603712                       Spore  purchase    1.0  0
# 4  151603712                       Spore      play   14.9  0

# %% [markdown]
# ### Data frame with games descriptions

# %% [markdown]
# this data set was sourced from kaggle: https://www.kaggle.com/nikdavis/steam-store-games

# %%
# game descriptions
df_3 = pd.read_csv('steam_description_data.csv')
df_3.head()
# Out:
#    steam_appid                               detailed_description  \
# 0           10  Play the world's number 1 online action game. ...
# 1           20  One of the most popular online action games of...
# 2           30  Enlist in an intense brand of Axis vs. Allied ...
# 3           40  Enjoy fast-paced multiplayer gaming with Death...
# 4           50  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...

# %% [markdown]
# ### Data frame with more games information

# %% [markdown]
# this data set was sourced from kaggle: https://www.kaggle.com/nikdavis/steam-store-games

# %%
# information
df_4 = pd.read_csv('steam.csv')
df_4.head()
# Out:
#    appid                       name release_date  english         developer publisher  \
# 0     10             Counter-Strike   2000-11-01        1             Valve     Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve     Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve     Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve     Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software     Valve
#
#            platforms  required_age                                         categories  genres  \
# 0  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2  windows;mac;linux             0              Multi-player;Valve Anti-Cheat enabled  Action
# 3  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  windows;mac;linux             0  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 0        Action;FPS;Multiplayer             0            124534              3339
# 1        Action;FPS;Multiplayer             0              3318               633
# 2  FPS;World War II;Multiplayer             0              3416               398
# 3        Action;FPS;Multiplayer             0              1273               267
# 4             FPS;Action;Sci-fi             0              5250               288
#
#    average_playtime  median_playtime             owners  price
# 0             17612              317  10000000-20000000   7.19
# 1               277               62   5000000-10000000   3.99
# 2               187               34   5000000-10000000   3.99
# 3               258              184   5000000-10000000   3.99
# 4               624              415   5000000-10000000   3.99

# %% [markdown]
# # Merging the data frames

# %%
# displaying data frame with steamspy data
df.head()
# Out:
#     appid                              name                         developer  \
# 0     570                            Dota 2                             Valve
# 1     730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 3     440                   Team Fortress 2                             Valve
# 4  304930                          Unturned             Smartly Dressed Games
#
#                publisher score_rank positive negative userscore                      owners  \
# 0                  Valve             1096061   194043         0  100,000,000 .. 200,000,000
# 1                  Valve             3828150   532417         0  100,000,000 .. 200,000,000
# 2       PUBG Corporation              780582   663880         0    20,000,000 .. 50,000,000
# 3                  Valve              626993    39149         0    20,000,000 .. 50,000,000
# 4  Smartly Dressed Games              348990    34793         0    20,000,000 .. 50,000,000
#
#   average_forever average_2weeks median_forever median_2weeks price initialprice discount
# 0           31602           1707           1211           876     0            0        0
# 1           27524           1201           8399           470     0            0        0
# 2           23253            663          10926           210  2999         2999        0
# 3            8201           1206            424           261     0            0        0
# 4            3158            969            326           612     0            0        0

# %%
# checking shape
df.shape
# Out:
# (35855, 16)

# %%
# checking data of the data frame containg game information
df_4.head()
# Out:
#    appid                       name release_date  english         developer publisher  \
# 0     10             Counter-Strike   2000-11-01        1             Valve     Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve     Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve     Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve     Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software     Valve
#
#            platforms  required_age                                         categories  genres  \
# 0  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2  windows;mac;linux             0              Multi-player;Valve Anti-Cheat enabled  Action
# 3  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  windows;mac;linux             0  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 0        Action;FPS;Multiplayer             0            124534              3339
# 1        Action;FPS;Multiplayer             0              3318               633
# 2  FPS;World War II;Multiplayer             0              3416               398
# 3        Action;FPS;Multiplayer             0              1273               267
# 4             FPS;Action;Sci-fi             0              5250               288
#
#    average_playtime  median_playtime             owners  price
# 0             17612              317  10000000-20000000   7.19
# 1               277               62   5000000-10000000   3.99
# 2               187               34   5000000-10000000   3.99
# 3               258              184   5000000-10000000   3.99
# 4               624              415   5000000-10000000   3.99

# %%
# checking shape
df_4.shape
# Out:
# (27075, 18)

# %%
# checking columns
df_4.columns
# Out:
# Index(['appid', 'name', 'release_date', 'english', 'developer', 'publisher', 'platforms',
#        'required_age', 'categories', 'genres', 'steamspy_tags', 'achievements', 'positive_ratings',
#        'negative_ratings', 'average_playtime', 'median_playtime', 'owners', 'price'],
#       dtype='object')

# %%
# checking columns
df.columns
# Out:
# Index(['appid', 'name', 'developer', 'publisher', 'score_rank', 'positive', 'negative',
#        'userscore', 'owners', 'average_forever', 'average_2weeks', 'median_forever',
#        'median_2weeks', 'price', 'initialprice', 'discount'],
#       dtype='object')

# %%
df[df['name'] == 'Dota 2']
# Out:
#   appid    name developer publisher score_rank positive negative userscore  \
# 0   570  Dota 2     Valve     Valve             1096061   194043         0
#
#                        owners average_forever average_2weeks median_forever median_2weeks price  \
# 0  100,000,000 .. 200,000,000           31602           1707           1211           876     0
#
#   initialprice discount
# 0            0        0

# %%
df_4[df_4.name == 'Dota 2']
# Out:
#     appid    name release_date  english developer publisher          platforms  required_age  \
# 22    570  Dota 2   2013-07-09        1     Valve     Valve  windows;mac;linux             0
#
#                                            categories                        genres  \
# 22  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
#
#                  steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 22  Free to Play;MOBA;Strategy             0            863507            142079
#
#     average_playtime  median_playtime               owners  price
# 22             23944              801  100000000-200000000    0.0

# %%
# dropping unessasary columns
df.drop(['price', 'initialprice', 'discount', 'average_2weeks', 'median_2weeks', 'owners'], axis=1, inplace=True)

# %%
# dropping unessasary columns
df_4.drop(['name', 'developer', 'publisher'], axis=1, inplace=True)

# %%
df_gameinfo = pd.DataFrame.merge(df,df_4,on='appid')

# %%
df_gameinfo.head()
# Out:
#     appid                              name                         developer  \
# 0     570                            Dota 2                             Valve
# 1     730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 3     440                   Team Fortress 2                             Valve
# 4  304930                          Unturned             Smartly Dressed Games
#
#                publisher score_rank positive negative userscore average_forever median_forever  \
# 0                  Valve             1096061   194043         0           31602           1211
# 1                  Valve             3828150   532417         0           27524           8399
# 2       PUBG Corporation              780582   663880         0           23253          10926
# 3                  Valve              626993    39149         0            8201            424
# 4  Smartly Dressed Games              348990    34793         0            3158            326
#
#   release_date  english          platforms  required_age  \
# 0   2013-07-09        1  windows;mac;linux             0
# 1   2012-08-21        1  windows;mac;linux             0
# 2   2017-12-21        1            windows             0
# 3   2007-10-10        1  windows;mac;linux             0
# 4   2017-07-07        1  windows;mac;linux             0
#
#                                           categories                                      genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...                Action;Free to Play;Strategy
# 1  Multi-player;Steam Achievements;Full controlle...                         Action;Free to Play
# 2             Multi-player;Online Multi-Player;Stats      Action;Adventure;Massively Multiplayer
# 3  Multi-player;Cross-Platform Multiplayer;Steam ...                         Action;Free to Play
# 4  Single-player;Online Multi-Player;Online Co-op...  Action;Adventure;Casual;Free to Play;Indie
#
#                    steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 0     Free to Play;MOBA;Strategy             0            863507            142079
# 1        FPS;Multiplayer;Shooter           167           2644404            402313
# 2   Survival;Shooter;Multiplayer            37            496184            487076
# 3   Free to Play;Multiplayer;FPS           520            515879             34036
# 4  Free to Play;Survival;Zombies            46            292574             31482
#
#    average_playtime  median_playtime               owners  price
# 0             23944              801  100000000-200000000   0.00
# 1             22494             6502   50000000-100000000   0.00
# 2             22938            12434   50000000-100000000  26.99
# 3              8495              623    20000000-50000000   0.00
# 4              3248              413    20000000-50000000   0.00

# %%
df_gameinfo.shape
# Out:
# (25974, 24)

# %%
df_gameinfo.columns
# Out:
# Index(['appid', 'name', 'developer', 'publisher', 'score_rank', 'positive', 'negative',
#        'userscore', 'average_forever', 'median_forever', 'release_date', 'english', 'platforms',
#        'required_age', 'categories', 'genres', 'steamspy_tags', 'achievements', 'positive_ratings',
#        'negative_ratings', 'average_playtime', 'median_playtime', 'owners', 'price'],
#       dtype='object')

# %%
df_3
# Out:
#        steam_appid                               detailed_description  \
# 0               10  Play the world's number 1 online action game. ...
# 1               20  One of the most popular online action games of...
# 2               30  Enlist in an intense brand of Axis vs. Allied ...
# 3               40  Enjoy fast-paced multiplayer gaming with Death...
# 4               50  Return to the Black Mesa Research Facility as ...
# ...            ...                                                ...
# 27329      1065230  <img src="https://steamcdn-a.akamaihd.net/stea...
# 27330      1065570  Have you ever been so lonely that no one but y...
# 27331      1065650  <strong>Super Star Blast </strong>is a space b...
# 27332      1066700  Pursue a snow-white deer through an enchanted ...
# 27333      1069460  A portal has opened and dark magic is pouring ...
#
#                                           about_the_game  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 27329  <img src="https://steamcdn-a.akamaihd.net/stea...
# 27330  Have you ever been so lonely that no one but y...
# 27331  <strong>Super Star Blast </strong>is a space b...
# 27332  Pursue a snow-white deer through an enchanted ...
# 27333  A portal has opened and dark magic is pouring ...
#
#                                        short_description
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 27329  The Room of Pandora is a third-person interact...
# 27330  Cyber Gun is a hardcore first-person shooter w...
# 27331  Super Star Blast is a space based game with ch...
# 27332  Pursue a snow-white deer through an enchanted ...
# 27333  A portal has opened and dark magic is pouring ...
#
# [27334 rows x 4 columns]

# %%
df_3.rename(columns={'steam_appid': 'appid'}, inplace=True)

# %%
df_gameinfo = pd.DataFrame.merge(df_gameinfo,df_3,on='appid')

# %%
df_gameinfo.head()
# Out:
#     appid                              name                         developer  \
# 0     570                            Dota 2                             Valve
# 1     730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 3     440                   Team Fortress 2                             Valve
# 4  304930                          Unturned             Smartly Dressed Games
#
#                publisher score_rank positive negative userscore average_forever median_forever  \
# 0                  Valve             1096061   194043         0           31602           1211
# 1                  Valve             3828150   532417         0           27524           8399
# 2       PUBG Corporation              780582   663880         0           23253          10926
# 3                  Valve              626993    39149         0            8201            424
# 4  Smartly Dressed Games              348990    34793         0            3158            326
#
#   release_date  english          platforms  required_age  \
# 0   2013-07-09        1  windows;mac;linux             0
# 1   2012-08-21        1  windows;mac;linux             0
# 2   2017-12-21        1            windows             0
# 3   2007-10-10        1  windows;mac;linux             0
# 4   2017-07-07        1  windows;mac;linux             0
#
#                                           categories                                      genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...                Action;Free to Play;Strategy
# 1  Multi-player;Steam Achievements;Full controlle...                         Action;Free to Play
# 2             Multi-player;Online Multi-Player;Stats      Action;Adventure;Massively Multiplayer
# 3  Multi-player;Cross-Platform Multiplayer;Steam ...                         Action;Free to Play
# 4  Single-player;Online Multi-Player;Online Co-op...  Action;Adventure;Casual;Free to Play;Indie
#
#                    steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 0     Free to Play;MOBA;Strategy             0            863507            142079
# 1        FPS;Multiplayer;Shooter           167           2644404            402313
# 2   Survival;Shooter;Multiplayer            37            496184            487076
# 3   Free to Play;Multiplayer;FPS           520            515879             34036
# 4  Free to Play;Survival;Zombies            46            292574             31482
#
#    average_playtime  median_playtime               owners  price  \
# 0             23944              801  100000000-200000000   0.00
# 1             22494             6502   50000000-100000000   0.00
# 2             22938            12434   50000000-100000000  26.99
# 3              8495              623    20000000-50000000   0.00
# 4              3248              413    20000000-50000000   0.00
#
#                                 detailed_description  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  Counter-Strike: Global Offensive (CS: GO) expa...
# 2  <strong>PLAYERUNKNOWN'S BATTLEGROUNDS</strong>...
# 3  <h1>The Jungle Inferno Update</h1><p><a href="...
# 4  <img src="https://steamcdn-a.akamaihd.net/stea...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  Counter-Strike: Global Offensive (CS: GO) expa...
# 2  <strong>PLAYERUNKNOWN'S BATTLEGROUNDS</strong>...
# 3  <p><strong>"The most fun you can have online"<...
# 4  <img src="https://steamcdn-a.akamaihd.net/stea...
#
#                                    short_description
# 0  Every day, millions of players worldwide enter...
# 1  Counter-Strike: Global Offensive (CS: GO) expa...
# 2  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 3  Nine distinct classes provide a broad range of...
# 4  You're a survivor in the zombie infested ruins...

# %%
df_2
# Out:
#         151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 0       151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 1       151603712                   Fallout 4  purchase    1.0  0
# 2       151603712                   Fallout 4      play   87.0  0
# 3       151603712                       Spore  purchase    1.0  0
# 4       151603712                       Spore      play   14.9  0
# ...           ...                         ...       ...    ... ..
# 199994  128470551                 Titan Souls      play    1.5  0
# 199995  128470551  Grand Theft Auto Vice City  purchase    1.0  0
# 199996  128470551  Grand Theft Auto Vice City      play    1.5  0
# 199997  128470551                        RUSH  purchase    1.0  0
# 199998  128470551                        RUSH      play    1.4  0
#
# [199999 rows x 5 columns]

# %%
df_2.rename(columns={'151603712': 'id', 'The Elder Scrolls V Skyrim': 'name', 
                     '1.0': 'hours_of_play'}, inplace=True)

# %%
df_2.head()
# Out:
#           id                        name  purchase  hours_of_play  0
# 0  151603712  The Elder Scrolls V Skyrim      play          273.0  0
# 1  151603712                   Fallout 4  purchase            1.0  0
# 2  151603712                   Fallout 4      play           87.0  0
# 3  151603712                       Spore  purchase            1.0  0
# 4  151603712                       Spore      play           14.9  0

# %%
df_2.columns
# Out:
# Index(['id', 'name', 'purchase', 'hours_of_play', '0'], dtype='object')

# %%
df_2['0'].unique()
# Out:
# array([0], dtype=int64)

# %%
del df_2['0']

# %%
df_2.head()
# Out:
#           id                        name  purchase  hours_of_play
# 0  151603712  The Elder Scrolls V Skyrim      play          273.0
# 1  151603712                   Fallout 4  purchase            1.0
# 2  151603712                   Fallout 4      play           87.0
# 3  151603712                       Spore  purchase            1.0
# 4  151603712                       Spore      play           14.9

# %%
df_2[df_2.name == 'Dota 2']
# Out:
#                id    name  purchase  hours_of_play
# 41      151603712  Dota 2  purchase            1.0
# 42      151603712  Dota 2      play            0.5
# 65      187131847  Dota 2  purchase            1.0
# 66      187131847  Dota 2      play            2.3
# 854     176410694  Dota 2  purchase            1.0
# ...           ...     ...       ...            ...
# 199896   99096740  Dota 2      play         1704.0
# 199947  176449171  Dota 2  purchase            1.0
# 199948  176449171  Dota 2      play         1310.0
# 199959  221315846  Dota 2  purchase            1.0
# 199960  221315846  Dota 2      play            9.0
#
# [9682 rows x 4 columns]

# %%
df_final = pd.DataFrame.merge(df_gameinfo,df_2,on='name')

# %%
df_final.head()
# Out:
#   appid    name developer publisher score_rank positive negative userscore average_forever  \
# 0   570  Dota 2     Valve     Valve             1096061   194043         0           31602
# 1   570  Dota 2     Valve     Valve             1096061   194043         0           31602
# 2   570  Dota 2     Valve     Valve             1096061   194043         0           31602
# 3   570  Dota 2     Valve     Valve             1096061   194043         0           31602
# 4   570  Dota 2     Valve     Valve             1096061   194043         0           31602
#
#   median_forever release_date  english          platforms  required_age  \
# 0           1211   2013-07-09        1  windows;mac;linux             0
# 1           1211   2013-07-09        1  windows;mac;linux             0
# 2           1211   2013-07-09        1  windows;mac;linux             0
# 3           1211   2013-07-09        1  windows;mac;linux             0
# 4           1211   2013-07-09        1  windows;mac;linux             0
#
#                                           categories                        genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 1  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 2  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 3  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 4  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
#
#                 steamspy_tags  achievements  positive_ratings  negative_ratings  average_playtime  \
# 0  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 1  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 2  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 3  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 4  Free to Play;MOBA;Strategy             0            863507            142079             23944
#
#    median_playtime               owners  price                               detailed_description  \
# 0              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 1              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 2              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 3              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 4              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  <strong>The most-played game on Steam.</strong...
# 2  <strong>The most-played game on Steam.</strong...
# 3  <strong>The most-played game on Steam.</strong...
# 4  <strong>The most-played game on Steam.</strong...
#
#                                    short_description         id  purchase  hours_of_play
# 0  Every day, millions of players worldwide enter...  151603712  purchase            1.0
# 1  Every day, millions of players worldwide enter...  151603712      play            0.5
# 2  Every day, millions of players worldwide enter...  187131847  purchase            1.0
# 3  Every day, millions of players worldwide enter...  187131847      play            2.3
# 4  Every day, millions of players worldwide enter...  176410694  purchase            1.0

# %%
df_final.shape
# Out:
# (99898, 30)

# %% [markdown]
# # DATA CLEANING

# %%
df = df_final

# %%
# detecting nan values in dataframe
df.isnull().values.any()
# Out:
# False

# %%
# locating where the nan values exist and the amount of nan values for each columns
df.isnull().sum()
# Out:
# appid                   0
# name                    0
# developer               0
# publisher               0
# score_rank              0
# positive                0
# negative                0
# userscore               0
# average_forever         0
# median_forever          0
# release_date            0
# english                 0
# platforms               0
# required_age            0
# categories              0
# genres                  0
# steamspy_tags           0
# achievements            0
# positive_ratings        0
# negative_ratings        0
# average_playtime        0
# median_playtime         0
# owners                  0
# price                   0
# detailed_description    0
# about_the_game          0
# short_description       0
# id                      0
# purchase                0
# hours_of_play           0
# dtype: int64

# %%
df.shape
# Out:
# (99898, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99898 entries, 0 to 99897
# Data columns (total 30 columns):
# appid                   99898 non-null object
# name                    99898 non-null object
# developer               99898 non-null object
# publisher               99898 non-null object
# score_rank              99898 non-null object
# positive                99898 non-null object
# negative                99898 non-null object
# userscore               99898 non-null object
# average_forever         99898 non-null object
# median_forever          99898 non-null object
# release_date            99898 non-null object
# english                 99898 non-null int64
# platforms               99898 non-null object
# required_age            99898 non-null int64
# categories              99898 non-null object
# genres                  99898 non-null object
# steamspy_tags           99898 non-null object
# achievements            99898 non-null int64
# positive_ratings        99898 non-null int64
# negative_ratings        99898 non-null int64
# average_playtime        99898 non-null int64
# median_playtime         99898 non-null int64
# owners                  99898 non-null object
# price                   99898 non-null float64
# detailed_description    99898 non-null object
# about_the_game          99898 non-null object
# short_description       99898 non-null object
# id                      99898 non-null int64
# purchase                99898 non-null object
# hours_of_play           99898 non-null float64
# dtypes: float64(2), int64(8), object(20)
# memory usage: 23.6+ MB

# %%
df.describe()
# Out:
#             english  required_age  achievements  positive_ratings  negative_ratings  \
# count  99898.000000  99898.000000  99898.000000      99898.000000      99898.000000
# mean       0.999690      2.231236     73.774870     157967.949969      21642.207792
# std        0.017613      5.813158    155.255117     263975.719136      42423.371777
# min        0.000000      0.000000      0.000000          0.000000          0.000000
# 25%        1.000000      0.000000      0.000000       3700.000000        661.000000
# 50%        1.000000      0.000000     29.000000      27755.000000       2609.000000
# 75%        1.000000      0.000000     67.000000     144595.000000      16433.000000
# max        1.000000     18.000000   1746.000000     863507.000000     142079.000000
#
#        average_playtime  median_playtime         price            id  hours_of_play
# count      99898.000000     99898.000000  99898.000000  9.989800e+04   99898.000000
# mean        4436.088300       590.911490      6.703205  1.134691e+08      21.733638
# std         7263.747083      1437.542446      7.575958  7.536131e+07     171.983658
# min            0.000000         0.000000      0.000000  5.250000e+03       0.100000
# 25%          258.000000       150.000000      0.000000  5.108578e+07       1.000000
# 50%          950.000000       364.000000      6.990000  1.010006e+08       1.000000
# 75%         4760.000000       801.000000      9.990000  1.668631e+08       2.000000
# max        95242.000000    190445.000000     69.990000  3.099031e+08   11754.000000

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df.head()
# Out:
#   appid    name developer publisher score_rank positive negative userscore average_forever  \
# 0   570  Dota 2     Valve     Valve             1096061   194043         0           31602
# 1   570  Dota 2     Valve     Valve             1096061   194043         0           31602
# 2   570  Dota 2     Valve     Valve             1096061   194043         0           31602
# 3   570  Dota 2     Valve     Valve             1096061   194043         0           31602
# 4   570  Dota 2     Valve     Valve             1096061   194043         0           31602
#
#   median_forever release_date  english          platforms  required_age  \
# 0           1211   2013-07-09        1  windows;mac;linux             0
# 1           1211   2013-07-09        1  windows;mac;linux             0
# 2           1211   2013-07-09        1  windows;mac;linux             0
# 3           1211   2013-07-09        1  windows;mac;linux             0
# 4           1211   2013-07-09        1  windows;mac;linux             0
#
#                                           categories                        genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 1  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 2  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 3  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 4  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
#
#                 steamspy_tags  achievements  positive_ratings  negative_ratings  average_playtime  \
# 0  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 1  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 2  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 3  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 4  Free to Play;MOBA;Strategy             0            863507            142079             23944
#
#    median_playtime               owners  price                               detailed_description  \
# 0              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 1              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 2              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 3              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 4              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  <strong>The most-played game on Steam.</strong...
# 2  <strong>The most-played game on Steam.</strong...
# 3  <strong>The most-played game on Steam.</strong...
# 4  <strong>The most-played game on Steam.</strong...
#
#                                    short_description         id  purchase  hours_of_play
# 0  Every day, millions of players worldwide enter...  151603712  purchase            1.0
# 1  Every day, millions of players worldwide enter...  151603712      play            0.5
# 2  Every day, millions of players worldwide enter...  187131847  purchase            1.0
# 3  Every day, millions of players worldwide enter...  187131847      play            2.3
# 4  Every day, millions of players worldwide enter...  176410694  purchase            1.0

# %%
df.columns
# Out:
# Index(['appid', 'name', 'developer', 'publisher', 'score_rank', 'positive', 'negative',
#        'userscore', 'average_forever', 'median_forever', 'release_date', 'english', 'platforms',
#        'required_age', 'categories', 'genres', 'steamspy_tags', 'achievements', 'positive_ratings',
#        'negative_ratings', 'average_playtime', 'median_playtime', 'owners', 'price',
#        'detailed_description', 'about_the_game', 'short_description', 'id', 'purchase',
#        'hours_of_play'],
#       dtype='object')

# %%
df = df[['id', 'appid', 'name', 'purchase', 'hours_of_play', 'developer',
       'publisher', 'score_rank', 'positive', 'negative', 'userscore', 'release_date', 'english',
       'platforms', 'required_age', 'categories', 'genres', 'steamspy_tags', 'achievements',
       'positive_ratings', 'negative_ratings', 'average_playtime', 'average_forever',
       'median_playtime', 'median_forever', 'owners', 'detailed_description', 'about_the_game',
       'short_description', 'price']]

# %%
df.columns
# Out:
# Index(['id', 'appid', 'name', 'purchase', 'hours_of_play', 'developer', 'publisher', 'score_rank',
#        'positive', 'negative', 'userscore', 'release_date', 'english', 'platforms', 'required_age',
#        'categories', 'genres', 'steamspy_tags', 'achievements', 'positive_ratings',
#        'negative_ratings', 'average_playtime', 'average_forever', 'median_playtime',
#        'median_forever', 'owners', 'detailed_description', 'about_the_game', 'short_description',
#        'price'],
#       dtype='object')

# %%
df.head()
# Out:
#           id appid    name  purchase  hours_of_play developer publisher score_rank positive  \
# 0  151603712   570  Dota 2  purchase            1.0     Valve     Valve             1096061
# 1  151603712   570  Dota 2      play            0.5     Valve     Valve             1096061
# 2  187131847   570  Dota 2  purchase            1.0     Valve     Valve             1096061
# 3  187131847   570  Dota 2      play            2.3     Valve     Valve             1096061
# 4  176410694   570  Dota 2  purchase            1.0     Valve     Valve             1096061
#
#   negative userscore release_date  english          platforms  required_age  \
# 0   194043         0   2013-07-09        1  windows;mac;linux             0
# 1   194043         0   2013-07-09        1  windows;mac;linux             0
# 2   194043         0   2013-07-09        1  windows;mac;linux             0
# 3   194043         0   2013-07-09        1  windows;mac;linux             0
# 4   194043         0   2013-07-09        1  windows;mac;linux             0
#
#                                           categories                        genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 1  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 2  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 3  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 4  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
#
#                 steamspy_tags  achievements  positive_ratings  negative_ratings  average_playtime  \
# 0  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 1  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 2  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 3  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 4  Free to Play;MOBA;Strategy             0            863507            142079             23944
#
#   average_forever  median_playtime median_forever               owners  \
# 0           31602              801           1211  100000000-200000000
# 1           31602              801           1211  100000000-200000000
# 2           31602              801           1211  100000000-200000000
# 3           31602              801           1211  100000000-200000000
# 4           31602              801           1211  100000000-200000000
#
#                                 detailed_description  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  <strong>The most-played game on Steam.</strong...
# 2  <strong>The most-played game on Steam.</strong...
# 3  <strong>The most-played game on Steam.</strong...
# 4  <strong>The most-played game on Steam.</strong...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  <strong>The most-played game on Steam.</strong...
# 2  <strong>The most-played game on Steam.</strong...
# 3  <strong>The most-played game on Steam.</strong...
# 4  <strong>The most-played game on Steam.</strong...
#
#                                    short_description  price
# 0  Every day, millions of players worldwide enter...    0.0
# 1  Every day, millions of players worldwide enter...    0.0
# 2  Every day, millions of players worldwide enter...    0.0
# 3  Every day, millions of players worldwide enter...    0.0
# 4  Every day, millions of players worldwide enter...    0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99898 entries, 0 to 99897
# Data columns (total 30 columns):
# id                      99898 non-null int64
# appid                   99898 non-null object
# name                    99898 non-null object
# purchase                99898 non-null object
# hours_of_play           99898 non-null float64
# developer               99898 non-null object
# publisher               99898 non-null object
# score_rank              99898 non-null object
# positive                99898 non-null object
# negative                99898 non-null object
# userscore               99898 non-null object
# release_date            99898 non-null datetime64[ns]
# english                 99898 non-null int64
# platforms               99898 non-null object
# required_age            99898 non-null int64
# categories              99898 non-null object
# genres                  99898 non-null object
# steamspy_tags           99898 non-null object
# achievements            99898 non-null int64
# positive_ratings        99898 non-null int64
# negative_ratings        99898 non-null int64
# average_playtime        99898 non-null int64
# average_forever         99898 non-null object
# median_playtime         99898 non-null int64
# median_forever          99898 non-null object
# owners                  99898 non-null object
# detailed_description    99898 non-null object
# about_the_game          99898 non-null object
# short_description       99898 non-null object
# price                   99898 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(19)
# memory usage: 23.6+ MB

# %%
df['id'].astype(str).astype(int)
# Out:
# 0        151603712
# 1        151603712
# 2        187131847
# 3        187131847
# 4        176410694
#            ...
# 99893     11373749
# 99894     55906572
# 99895     17530772
# 99896    192170147
# 99897    154230723
# Name: id, Length: 99898, dtype: int32

# %%
df['appid'] = df['appid'].astype(str).astype('int64')

# %%
df.dtypes
# Out:
# id                               int64
# appid                            int64
# name                            object
# purchase                        object
# hours_of_play                  float64
# developer                       object
# publisher                       object
# score_rank                      object
# positive                        object
# negative                        object
# userscore                       object
# release_date            datetime64[ns]
# english                          int64
# platforms                       object
# required_age                     int64
# categories                      object
# genres                          object
# steamspy_tags                   object
# achievements                     int64
# positive_ratings                 int64
# negative_ratings                 int64
# average_playtime                 int64
# average_forever                 object
# median_playtime                  int64
# median_forever                  object
# owners                          object
# detailed_description            object
# about_the_game                  object
# short_description               object
# price                          float64
# dtype: object

# %%
df.name.unique()
# Out:
# array(['Dota 2', 'Team Fortress 2', 'Unturned', ..., 'Project Aftermath',
#        "YOU DON'T KNOW JACK Vol. 2", "YOU DON'T KNOW JACK TELEVISION"],
#       dtype=object)

# %%
df.score_rank.unique()
# Out:
# array([''], dtype=object)

# %%
df.userscore.unique()
# Out:
# array([0], dtype=object)

# %%
# deleting the unessesary columns
del df['userscore']
del df['score_rank']
del df['average_forever']
del df['median_forever']

# %%
# creating a new column to show the percentage of positive ratings of games
# adding the positive and negative columns
df['rank'] = df['positive'] + df['negative']

# %%
# dividing positive column by the rank column
df['rank'] = df['positive']/df['rank']

# %%
# multiplying rank by 100 to get percentage
df['rank'] = df['rank'] * 100

# %% [markdown]
# # Saving the final cleaned data frame to a csv file

# %%
df.to_csv('steam_rs.csv', index=False)
