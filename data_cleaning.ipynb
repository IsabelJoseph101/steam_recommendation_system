# %% [markdown]
# # STEAM VIDEO GAMES RECOMMENDATION SYSTEM

# %% [markdown]
# # BUSINESS PROBLEM

# %% [markdown]
# Steam is the largest video game hosting platform in the market with a large caleloge full of games. With access to such a variety of games, sometimes users may feel overwelmed, or feel unsure with where to start, there for it is absolutely vital that both customers new and old are provided with recommendended suitable games that align with their specific preferences.
# <br><br>
# Therefore for this project i decided to create a recommendation system for steam games to help users find suitable game recommendations that they would be interested in. My goal for this project is to provide more accurate predictions regarding providing a user with recommendations.
# <br><br>
# For this project i will be creating a content and collaborative based recommendation model that provides video game recommendations to steam users. This project will utlize Steam's API, SteamSpy's API along with data sets sourced from kaggle in order to create a recommendation system.
# <br><br>
# The aim of this project is to improve steam's current recommendation system to provide users with much more accurate recommendations.

# %% [markdown]
# # DATA PREPARATION

# %% [markdown]
# ### Importing necessary packages

# %%
# importing necessary packages
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import json
import requests
from bs4 import BeautifulSoup

from sklearn.preprocessing import StandardScaler 
from sklearn import preprocessing

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# # Obtaining the API key

# %%
# function that obtains api key from folder
def get_keys(path):
    ''' this function obtains the api key'''
    with open(path) as f:
        return json.load(f)

# %%
# getting the api key
keys = get_keys("/Users/Visitor/Documents/Flatiron/Capstone/.secret/steam_api.json")

# %%
# getting and assigning the api key to a variable
api_key = keys['api_key']

# %% [markdown]
# # Generating requests from Steam's API

# %% [markdown]
# I will be using steams API to gain information regarding player informatoin, their recently played games, friends lists, users statistics for a particular game and a list of all steam games.

# %% [markdown]
# From Steam's api the following data will be used:
# <li>GetPlayerSummaries
# <li>GetUserStatsForGame
# <li>GetRecentlyPlayedGames
# <li>GetOwnedGames
# <li>GetFriendList
# <li>GetAppList

# %% [markdown]
# This data is obtained from: https://steamcommunity.com/dev

# %% [markdown]
# ### Player summaries (GetPlayerSummaries)

# %% [markdown]
# Player summaries provides their steam id, along with other user information.

# %%
# getting requests from the api for the player summaries
resp = requests.get("http://api.steampowered.com/ISteamUser/GetPlayerSummaries/v0002/?key=B8DD767E6A0BF4F61B05D6E5483C29A9&steamids=76561197960435530")

# %%
# checking if the request was sucessful
resp.status_code == requests.codes.ok
# Out:
# True

# %%
#filtering the data
resp.json()['response']['players']
# Out:
# [{'steamid': '76561197960435530',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Robin',
#   'profileurl': 'https://steamcommunity.com/id/robinwalker/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/f1/f1dd60a188883caf82d0cbfccfe6aba0af1732d4.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/f1/f1dd60a188883caf82d0cbfccfe6aba0af1732d4_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/f1/f1dd60a188883caf82d0cbfccfe6aba0af1732d4_full.jpg',
#   'avatarhash': 'f1dd60a188883caf82d0cbfccfe6aba0af1732d4',
#   'personastate': 0,
#   'realname': 'Robin Walker',
#   'primaryclanid': '103582791429521412',
#   'timecreated': 1063407589,
#   'personastateflags': 0,
#   'loccountrycode': 'US',
#   'locstatecode': 'WA',
#   'loccityid': 3961}]

# %%
# creating a data frame using the obtained information
df = pd.DataFrame.from_dict(resp.json()['response']['players'])

# %%
# displaying the data frame
df.head()
# Out:
#              steamid  communityvisibilitystate  profilestate personaname  \
# 0  76561197960435530                         3             1       Robin
#
#                                    profileurl                                             avatar  \
# 0  https://steamcommunity.com/id/robinwalker/  https://steamcdn-a.akamaihd.net/steamcommunity...
#
#                                         avatarmedium  \
# 0  https://steamcdn-a.akamaihd.net/steamcommunity...
#
#                                           avatarfull                                avatarhash  \
# 0  https://steamcdn-a.akamaihd.net/steamcommunity...  f1dd60a188883caf82d0cbfccfe6aba0af1732d4
#
#    personastate      realname       primaryclanid  timecreated  personastateflags loccountrycode  \
# 0             0  Robin Walker  103582791429521412   1063407589                  0             US
#
#   locstatecode  loccityid
# 0           WA       3961

# %% [markdown]
# ### Friend's list (GetFriendList)

# %% [markdown]
# Friends list, generates a list of all friends for a specific user. Having this information will further help identify which games to recommend a user as it could be the case that these friends could have similar preferences, and therefore may like similar games

# %%
# getting requests from the api for users friend lists
resp = requests.get("http://api.steampowered.com/ISteamUser/GetFriendList/v0001/?key=B8DD767E6A0BF4F61B05D6E5483C29A9&steamid=76561197960435530&relationship=friend")

# %%
# checking if the request was sucessful
resp.status_code == requests.codes.ok
# Out:
# True

# %%
# filtering the data
# resp.json()['friendslist']['friends']

# %%
# creating a data frame from the obtained data
df = pd.DataFrame.from_dict(resp.json()['friendslist']['friends'])

# %%
# displaying the newly created data frame
df.head()
# Out:
#              steamid relationship  friend_since
# 0  76561197960265731       friend             0
# 1  76561197960265738       friend             0
# 2  76561197960265740       friend             0
# 3  76561197960265744       friend    1585508613
# 4  76561197960265747       friend             0

# %% [markdown]
# ### List of all games (GetAppList)

# %%
# obtaining requests from the api to get a list of steam games
resp = requests.get("https://api.steampowered.com/ISteamApps/GetAppList/v2/")

# %%
# checking if the request was sucessful
resp.status_code == requests.codes.ok
# Out:
# True

# %%
#filtering the data
#resp.json()['applist']['apps']

# %%
# creating a data frame with the obtained data
df_games = pd.DataFrame.from_dict(resp.json()['applist']['apps'])

# %%
# displaying the data frame
df_games.head()
# Out:
#     appid                                    name
# 0  216938           Pieterw test app76 ( 216938 )
# 1  660010                                   test2
# 2  660130                                   test3
# 3  657500  Hold the Line: The American Revolution
# 4  657510                                TUBELIVE

# %% [markdown]
# # Generating requests from SteamSpy

# %% [markdown]
# As i was unable to source all of the game information from steam's api, i will be using steamspy, which contains an entire list of steam games, their app id, genres and all other relevent information.

# %% [markdown]
# This data is obtained from: https://steamspy.com/

# %% [markdown]
# ### Using steamspy to request steam's game information

# %%
# requesting all game data from steamspy
resp = requests.get("http://steamspy.com/api.php?request=all")

# %%
# converting the request to json format
dic_app_user = resp.json()

# %%
# obtaining the keys of the dictionary
lst_app_id = dic_app_user.keys()

# %%
# checking length
len(dic_app_user)
# Out:
# 35935

# %%
# checking if the request was sucessful
resp.status_code == requests.codes.ok
# Out:
# True

# %%
# filtering the data
# resp.json()

# %%
# converting the dictionary to a data frame
df = pd.DataFrame.from_dict(resp.json())

# %%
# displaying the data frame
df
# Out:
#                                         570                               730  \
# appid                                   570                               730
# name                                 Dota 2  Counter-Strike: Global Offensive
# developer                             Valve  Valve, Hidden Path Entertainment
# publisher                             Valve                             Valve
# score_rank
# positive                            1097301                           3837538
# negative                             194384                            533489
# userscore                                 0                                 0
# owners           100,000,000 .. 200,000,000        100,000,000 .. 200,000,000
# average_forever                       31658                             26845
# average_2weeks                         1716                              1263
# median_forever                         1312                              8022
# median_2weeks                           823                               421
# price                                     0                                 0
# initialprice                              0                                 0
# discount                                  0                                 0
#
#                                         578080                       440  \
# appid                                   578080                       440
# name             PLAYERUNKNOWN'S BATTLEGROUNDS           Team Fortress 2
# developer                     PUBG Corporation                     Valve
# publisher                     PUBG Corporation                     Valve
# score_rank
# positive                                782126                    627753
# negative                                665184                     39210
# userscore                                    0                         0
# owners                20,000,000 .. 50,000,000  20,000,000 .. 50,000,000
# average_forever                          23329                     10329
# average_2weeks                             766                      1598
# median_forever                           11603                       426
# median_2weeks                              240                       513
# price                                     2999                         0
# initialprice                              2999                         0
# discount                                     0                         0
#
#                                    304930                    230410  \
# appid                              304930                    230410
# name                             Unturned                  Warframe
# developer           Smartly Dressed Games          Digital Extremes
# publisher           Smartly Dressed Games          Digital Extremes
# score_rank
# positive                           349381                    327865
# negative                            34828                     32662
# userscore                               0                         0
# owners           20,000,000 .. 50,000,000  20,000,000 .. 50,000,000
# average_forever                      2817                      8247
# average_2weeks                        789                      1263
# median_forever                        344                       457
# median_2weeks                         816                       318
# price                                   0                         0
# initialprice                            0                         0
# discount                                0                         0
#
#                                          359550                    271590  \
# appid                                    359550                    271590
# name             Tom Clancy's Rainbow Six Siege        Grand Theft Auto V
# developer                      Ubisoft Montreal            Rockstar North
# publisher                               Ubisoft            Rockstar Games
# score_rank
# positive                                 598659                    689538
# negative                                  84452                    176542
# userscore                                     0                         0
# owners                 20,000,000 .. 50,000,000  20,000,000 .. 50,000,000
# average_forever                           11052                     11238
# average_2weeks                              712                       794
# median_forever                             3131                      5106
# median_2weeks                               547                       282
# price                                      1999                      2999
# initialprice                               1999                      2999
# discount                                      0                         0
#
#                                    291550                    105600                       550  \
# appid                              291550                    105600                       550
# name                           Brawlhalla                  Terraria             Left 4 Dead 2
# developer              Blue Mammoth Games                  Re-Logic                     Valve
# publisher                         Ubisoft                  Re-Logic                     Valve
# score_rank
# positive                           128647                    495595                    345011
# negative                            22819                     11039                     10423
# userscore                               0                         0                         0
# owners           20,000,000 .. 50,000,000  20,000,000 .. 50,000,000  20,000,000 .. 50,000,000
# average_forever                      1826                      6044                      1853
# average_2weeks                        208                       676                       170
# median_forever                        210                      2377                       556
# median_2weeks                          74                       414                       144
# price                                   0                       999                       999
# initialprice                            0                       999                       999
# discount                                0                         0                         0
#
#                                      4000                        10                       340  \
# appid                                4000                        10                       340
# name                          Garry's Mod            Counter-Strike   Half-Life 2: Lost Coast
# developer               Facepunch Studios                     Valve                     Valve
# publisher                           Valve                     Valve                     Valve
# score_rank
# positive                           536350                    154297                      6884
# negative                            20390                      4019                      1107
# userscore                               0                         0                         0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                     10286                      8277                        48
# average_2weeks                        571                      1247                         0
# median_forever                       1560                       201                        20
# median_2weeks                         195                       212                         0
# price                                 999                       999                         0
# initialprice                          999                       999                         0
# discount                                0                         0                         0
#
#                                    444090                    272060                       240  \
# appid                              444090                    272060                       240
# name                             Paladins                    Serena    Counter-Strike: Source
# developer                 Evil Mojo Games                  Senscape                     Valve
# publisher                  Hi-Rez Studios                  Senscape                     Valve
# score_rank
# positive                           227745                      4735                    100908
# negative                            38839                      1415                      4213
# userscore                               0                         0                         0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                      2338                        73                      5555
# average_2weeks                        333                         0                        52
# median_forever                        513                         3                       364
# median_2weeks                          71                         0                        77
# price                                   0                         0                       999
# initialprice                            0                         0                       999
# discount                                0                         0                         0
#
#                                    236390                    238960  \
# appid                              236390                    238960
# name                          War Thunder             Path of Exile
# developer            Gaijin Entertainment       Grinding Gear Games
# publisher         Gaijin Distribution KFT       Grinding Gear Games
# score_rank
# positive                           126752                    122965
# negative                            30535                      8884
# userscore                               0                         0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                      3767                      5130
# average_2weeks                        409                      1105
# median_forever                        371                       352
# median_2weeks                         263                      1448
# price                                   0                         0
# initialprice                            0                         0
# discount                                0                         0
#
#                                           218620                                         49520  \
# appid                                     218620                                         49520
# name                                    PAYDAY 2                                 Borderlands 2
# developer        OVERKILL - a Starbreeze Studio.  Gearbox Software, Aspyr (Mac), Aspyr (Linux)
# publisher               Starbreeze Publishing AB                2K, Aspyr (Mac), Aspyr (Linux)
# score_rank
# positive                                  376348                                        211545
# negative                                   58188                                         15121
# userscore                                      0                                             0
# owners                  10,000,000 .. 20,000,000                      10,000,000 .. 20,000,000
# average_forever                             4765                                          2776
# average_2weeks                               884                                           160
# median_forever                               816                                           976
# median_2weeks                               1059                                           236
# price                                        999                                          1999
# initialprice                                 999                                          1999
# discount                                       0                                             0
#
#                                    227940                   1085660                    301520  \
# appid                              227940                   1085660                    301520
# name                    Heroes & Generals                 Destiny 2                 Robocraft
# developer                       RETO MOTO                    Bungie                   Freejam
# publisher                       RETO MOTO                   Bungie                    Freejam
# score_rank
# positive                            79771                    203798                     84125
# negative                            38923                     30165                     32053
# userscore                               0                         0                         0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                       884                      3532                      1030
# average_2weeks                        121                      1299                         8
# median_forever                         85                       504                       200
# median_2weeks                         148                       706                         8
# price                                   0                         0                         0
# initialprice                            0                         0                         0
# discount                                0                         0                         0
#
#                                    252950                    291480                    219990  \
# appid                              252950                    291480                    219990
# name                        Rocket League                   Warface                 Grim Dawn
# developer                     Psyonix LLC                  MY.GAMES       Crate Entertainment
# publisher                     Psyonix LLC                  MY.GAMES       Crate Entertainment
# score_rank
# positive                           380820                     39627                     46780
# negative                            39515                     17341                      3692
# userscore                               0                         0                         0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                     10395                      1168                      4268
# average_2weeks                        392                      1489                       634
# median_forever                       1686                       107                      1093
# median_2weeks                         164                      2976                       843
# price                                1999                         0                      2499
# initialprice                         1999                         0                      2499
# discount                                0                         0                         0
#
#                                       220                    252490                           360  \
# appid                                 220                    252490                           360
# name                          Half-Life 2                      Rust  Half-Life Deathmatch: Source
# developer                           Valve         Facepunch Studios                         Valve
# publisher                           Valve         Facepunch Studios                         Valve
# score_rank
# positive                            97868                    367747                          1788
# negative                             2895                     72708                           566
# userscore                               0                         0                             0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000      10,000,000 .. 20,000,000
# average_forever                       545                     14018                            31
# average_2weeks                        458                      1731                             8
# median_forever                        324                      2576                            16
# median_2weeks                         458                      1268                             8
# price                                 999                      3999                           999
# initialprice                          999                      3999                           999
# discount                                0                         0                             0
#
#                                    304050                       620                    433850  \
# appid                              304050                       620                    433850
# name                                Trove                  Portal 2          Z1 Battle Royale
# developer                    Trion Worlds                     Valve     Daybreak Game Company
# publisher                    Trion Worlds                     Valve     Daybreak Game Company
# score_rank
# positive                            58420                    191190                    114914
# negative                            14984                      2430                     93833
# userscore                               0                         0                         0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  10,000,000 .. 20,000,000
# average_forever                      2256                       826                      3027
# average_2weeks                         71                       102                       683
# median_forever                        207                       503                       223
# median_2weeks                          96                        97                       683
# price                                   0                       999                         0
# initialprice                            0                       999                         0
# discount                                0                         0                         0
#
#                                    550650                    386360                    96000  \
# appid                              550650                    386360                    96000
# name                          Black Squad                     SMITE      The Tiny Bang Story
# developer                       NS STUDIO         Titan Forge Games            Colibri Games
# publisher                       NS STUDIO            Hi-Rez Studios            Colibri Games
# score_rank
# positive                            52378                     52453                     4565
# negative                            15143                     12490                      650
# userscore                               0                         0                        0
# owners           10,000,000 .. 20,000,000  10,000,000 .. 20,000,000  5,000,000 .. 10,000,000
# average_forever                      1037                      2537                      287
# average_2weeks                        811                       640                        0
# median_forever                         87                       173                      303
# median_2weeks                         501                       779                        0
# price                                   0                         0                      499
# initialprice                            0                         0                      499
# discount                                0                         0                        0
#
#                                    44350                        72850  \
# appid                              44350                        72850
# name                              GRID 2  The Elder Scrolls V: Skyrim
# developer             Codemasters Racing        Bethesda Game Studios
# publisher                    Codemasters           Bethesda Softworks
# score_rank
# positive                           20104                       266673
# negative                            4230                        15299
# userscore                              0                            0
# owners           5,000,000 .. 10,000,000      5,000,000 .. 10,000,000
# average_forever                      635                         7046
# average_2weeks                        95                          238
# median_forever                       202                         2859
# median_2weeks                        181                          427
# price                                  0                         1999
# initialprice                           0                         1999
# discount                               0                            0
#
#                                                       8930                   417910  \
# appid                                                 8930                   417910
# name                            Sid Meier's Civilization V   Street Warriors Online
# developer        Firaxis Games, Aspyr (Mac), Aspyr (Linux)      Crazy Rocks Studios
# publisher                   2K, Aspyr (Mac), Aspyr (Linux)      Crazy Rocks Studios
# score_rank
# positive                                            154930                      988
# negative                                              6271                      730
# userscore                                                0                        0
# owners                             5,000,000 .. 10,000,000  5,000,000 .. 10,000,000
# average_forever                                      13066                       55
# average_2weeks                                         879                        0
# median_forever                                        2615                       69
# median_2weeks                                         1412                        0
# price                                                 2999                      199
# initialprice                                          2999                      199
# discount                                                 0                        0
#
#                                              80                      381210  \
# appid                                        80                      381210
# name             Counter-Strike: Condition Zero            Dead by Daylight
# developer                                 Valve  Behaviour Interactive Inc.
# publisher                                 Valve  Behaviour Interactive Inc.
# score_rank
# positive                                  15099                      247565
# negative                                   1588                       61143
# userscore                                     0                           0
# owners                  5,000,000 .. 10,000,000     5,000,000 .. 10,000,000
# average_forever                             317                        7922
# average_2weeks                                5                        1097
# median_forever                               42                        1084
# median_2weeks                                 6                         316
# price                                       999                        1999
# initialprice                                999                        1999
# discount                                      0                           0
#
#                                    292030                   431960                   582010  \
# appid                              292030                   431960                   582010
# name             The Witcher 3: Wild Hunt         Wallpaper Engine    MONSTER HUNTER: WORLD
# developer                  CD PROJEKT RED    Wallpaper Engine Team         CAPCOM Co., Ltd.
# publisher                  CD PROJEKT RED    Wallpaper Engine Team         CAPCOM Co., Ltd.
# score_rank
# positive                           364706                   172169                   199892
# negative                             7045                     3121                    43701
# userscore                               0                        0                        0
# owners            5,000,000 .. 10,000,000  5,000,000 .. 10,000,000  5,000,000 .. 10,000,000
# average_forever                      3437                     2055                     8299
# average_2weeks                        675                      129                      601
# median_forever                       1331                      581                     4026
# median_2weeks                         184                       20                      251
# price                                1199                      399                     2999
# initialprice                         3999                      399                     2999
# discount                               70                        0                        0
#
#                                   218230                       70                      320  \
# appid                             218230                       70                      320
# name                        PlanetSide 2                Half-Life  Half-Life 2: Deathmatch
# developer             Rogue Planet Games                    Valve                    Valve
# publisher          Daybreak Game Company                    Valve                    Valve
# score_rank
# positive                           44734                    45008                     7441
# negative                            9117                     1685                      871
# userscore                              0                        0                        0
# owners           5,000,000 .. 10,000,000  5,000,000 .. 10,000,000  5,000,000 .. 10,000,000
# average_forever                      994                      582                      377
# average_2weeks                       216                       98                        0
# median_forever                       234                      163                       51
# median_2weeks                        372                      189                        0
# price                                  0                      999                      499
# initialprice                           0                      999                      499
# discount                               0                        0                        0
#
#                                   755790                   370910  ...       889680  \
# appid                             755790                   370910  ...       889680
# name                     Ring of Elysium               Kathy Rain  ...          Her
# developer                  Aurora Studio           Clifftop Games  ...          橘喵喵
# publisher            TCH Scarlet Limited                 Raw Fury  ...          橘喵喵
# score_rank                                                         ...
# positive                           67010                     2431  ...            0
# negative                           21081                      192  ...            0
# userscore                              0                        0  ...            0
# owners           5,000,000 .. 10,000,000  5,000,000 .. 10,000,000  ...  0 .. 20,000
# average_forever                      845                      817  ...            0
# average_2weeks                        24                        0  ...            0
# median_forever                       114                      261  ...            0
# median_2weeks                         24                        0  ...            0
# price                                  0                     1499  ...            0
# initialprice                           0                     1499  ...            0
# discount                               0                        0  ...            0
#
#                                  763340          709970       490360          613050  \
# appid                            763340          709970       490360          613050
# name                         Brave Hand  SwapQuest Demo      Hermodr      Laser Grid
# developer        Heart Shaped Games LLC                  Regday NULL  Selenion Games
# publisher        Heart Shaped Games LLC                  Regday NULL  Selenion Games
# score_rank
# positive                              0               0            0               0
# negative                              0               0            0               0
# userscore                             0               0            0               0
# owners                      0 .. 20,000     0 .. 20,000  0 .. 20,000     0 .. 20,000
# average_forever                       0               0            0               0
# average_2weeks                        0               0            0               0
# median_forever                        0               0            0               0
# median_2weeks                         0               0            0               0
# price                                 0            None            0               0
# initialprice                          0            None            0               0
# discount                              0            None            0               0
#
#                                                  99110                  668620        804910  \
# appid                                            99110                  668620        804910
# name             Dungeons & Dragons: Daggerdale - Demo  1Dimensional Desperado   Mine Seeker
# developer                                                          White Mouse  Jason Crosby
# publisher                                                          White Mouse  Jason Crosby
# score_rank
# positive                                             0                       0             0
# negative                                             0                       0             0
# userscore                                            0                       0             0
# owners                                     0 .. 20,000             0 .. 20,000   0 .. 20,000
# average_forever                                      0                       0             0
# average_2weeks                                       0                       0             0
# median_forever                                       0                       0             0
# median_2weeks                                        0                       0             0
# price                                                0                       0           799
# initialprice                                         0                       0           799
# discount                                             0                       0             0
#
#                                        804540                   865810         723360  \
# appid                                  804540                   865810         723360
# name             Greedy Developer's Cash Grab  Waifu Fight Dango Style        Asunder
# developer                    Greedy Developer       Enso Entertainment  Dawson Frakes
# publisher                    Greedy Publisher       Enso Entertainment  Dawson Frakes
# score_rank
# positive                                    0                        0              0
# negative                                    0                        0              0
# userscore                                   0                        0              0
# owners                            0 .. 20,000              0 .. 20,000    0 .. 20,000
# average_forever                             0                        0              0
# average_2weeks                              0                        0              0
# median_forever                              0                        0              0
# median_2weeks                               0                        0              0
# price                                       0                        0              0
# initialprice                                0                        0              0
# discount                                    0                        0              0
#
#                       593150               599490                       743920          785790  \
# appid                 593150               599490                       743920          785790
# name                 Ooblets        Bounty Killer  Choo-Choo! The Train Rides!  WHAT THE GOLF?
# developer        Glumberland   Galaxy Game Studio                     SE Games         Triband
# publisher        Glumberland  Galaxy Game Studio                      SeStudio         Triband
# score_rank
# positive                   0                    0                            0               0
# negative                   0                    0                            0               0
# userscore                  0                    0                            0               0
# owners           0 .. 20,000          0 .. 20,000                  0 .. 20,000     0 .. 20,000
# average_forever            0                    0                            0               0
# average_2weeks             0                    0                            0               0
# median_forever             0                    0                            0               0
# median_2weeks              0                    0                            0               0
# price                      0                    0                            0               0
# initialprice               0                    0                            0               0
# discount                   0                    0                            0               0
#
#                                    611820           652730           789710        729290  \
# appid                              611820           652730           789710        729290
# name             Xenosis: Alien Infection     Z-Aftershock  BoyAndLabyrinth  Hidden Cubes
# developer                NerdRage Studios  Mango Tree Game          WBTgame    NixieCraft
# publisher                NerdRage Studios  Mango Tree Game          WBTgame    NixieCraft
# score_rank
# positive                                0                0                0             0
# negative                                0                0                0             0
# userscore                               0                0                0             0
# owners                        0 .. 20,000      0 .. 20,000      0 .. 20,000   0 .. 20,000
# average_forever                         0                0                0             0
# average_2weeks                          0                0                0             0
# median_forever                          0                0                0             0
# median_2weeks                           0                0                0             0
# price                                   0                0              499           599
# initialprice                            0                0              499           599
# discount                                0                0                0             0
#
#                              705000         541310                 736240  \
# appid                        705000         541310                 736240
# name                     OctorSpace      Tiny Thor  The Revolt: Awakening
# developer        DrinkingNails, LLC  Asylum Square        Siberius Studio
# publisher        DrinkingNails, LLC  Asylum Square        Siberius Studio
# score_rank
# positive                          0              0                      0
# negative                          0              0                      0
# userscore                         0              0                      0
# owners                  0 .. 20,000    0 .. 20,000            0 .. 20,000
# average_forever                   0              0                      0
# average_2weeks                    0              0                      0
# median_forever                    0              0                      0
# median_2weeks                     0              0                      0
# price                             0              0                      0
# initialprice                      0              0                      0
# discount                          0              0                      0
#
#                                     750200            751270                   761720  \
# appid                               750200            751270                   761720
# name             AWAY: The Survival Series         BioEntity  Can you eat by yourself
# developer                   Breaking Walls  Sneaky Party LLC         Independent team
# publisher                   Breaking Walls  Sneaky Party LLC         Independent team
# score_rank
# positive                                 0                 0                        0
# negative                                 0                 0                        0
# userscore                                0                 0                        0
# owners                         0 .. 20,000       0 .. 20,000              0 .. 20,000
# average_forever                          0                 0                        0
# average_2weeks                           0                 0                        0
# median_forever                           0                 0                        0
# median_2weeks                            0                 0                        0
# price                                    0                 0                        0
# initialprice                             0                 0                        0
# discount                                 0                 0                        0
#
#                              852        701360               18310        17760  \
# appid                        852        701360               18310        17760
# name             ValveTestApp852  Fate Crawler  Spectraball - Demo
# developer                           MixerGames
# publisher                           MixerGames
# score_rank
# positive                       0             0                   0            0
# negative                       0             0                   0            0
# userscore                      0             0                   0            0
# owners               0 .. 20,000   0 .. 20,000         0 .. 20,000  0 .. 20,000
# average_forever                0             0                   0            0
# average_2weeks                 0             0                   0            0
# median_forever                 0             0                   0            0
# median_2weeks                  0             0                   0            0
# price                          0             0                   0            0
# initialprice                   0             0                   0            0
# discount                       0             0                   0            0
#
#                                    497960               721460               859120  \
# appid                              497960               721460               859120
# name             Legends of Callasia Demo  Xeno Time Inception  That Tiny Spaceship
# developer                                      Xeno Gaming LLC  We Make Small Games
# publisher                                      Xeno Gaming LLC  We Make Small Games
# score_rank
# positive                                0                    0                    0
# negative                                0                    0                    0
# userscore                               0                    0                    0
# owners                        0 .. 20,000          0 .. 20,000          0 .. 20,000
# average_forever                         0                    0                    0
# average_2weeks                          0                    0                    0
# median_forever                          0                    0                    0
# median_2weeks                           0                    0                    0
# price                                None                    0                    0
# initialprice                         None                    0                    0
# discount                             None                    0                    0
#
#                          512720               848400            643930                    553140  \
# appid                    512720               848400            643930                    553140
# name             Velocidevorium        Simian Rising  拯救大魔王3 Falsemen3              Green Mirror
# developer          Really Slick  All Caps Industries           吃了就睡工作室  Bad2theBone, Glumpy Fish
# publisher          Really Slick  All Caps Industries           吃了就睡工作室               Glumpy Fish
# score_rank
# positive                      0                    0                 0                         0
# negative                      0                    0                 0                         0
# userscore                     0                    0                 0                         0
# owners              0 .. 20,000          0 .. 20,000       0 .. 20,000               0 .. 20,000
# average_forever               0                    0                 0                         0
# average_2weeks                0                    0                 0                         0
# median_forever                0                    0                 0                         0
# median_2weeks                 0                    0                 0                         0
# price                         0                 1299                 0                         0
# initialprice                  0                 1299                 0                         0
# discount                      0                    0                 0                         0
#
#                         201930            675330       778140       591020         646240  \
# appid                   201930            675330       778140       591020         646240
# name             Jamestown IGF       Space Crawl      BRIKS 2           山贼  Bacon May Die
# developer                       Hyperfine Studio      Smobile       Tushuo        SnoutUp
# publisher                       Hyperfine Studio      Smobile       Tushuo        SnoutUp
# score_rank
# positive                     0                 0            0            0              0
# negative                     0                 0            0            0              0
# userscore                    0                 0            0            0              0
# owners             0 .. 20,000       0 .. 20,000  0 .. 20,000  0 .. 20,000    0 .. 20,000
# average_forever              0                 0            0            0              0
# average_2weeks               0                 0            0            0              0
# median_forever               0                 0            0            0              0
# median_2weeks                0                 0            0            0              0
# price                        0                 0          999            0              0
# initialprice                 0                 0          999            0              0
# discount                     0                 0            0            0              0
#
#                       858730                                             651490          654200  \
# appid                 858730                                             651490          654200
# name              Yoke Light                                     No Longer Home   Seven: Reboot
# developer          Kotoshiro  Humble Grove, Hana Lee, Cel Davison, Adrienne ...  CakeEaterGames
# publisher          Kotoshiro                                       Humble Grove  CakeEaterGames
# score_rank
# positive                   0                                                  0               0
# negative                   0                                                  0               0
# userscore                  0                                                  0               0
# owners           0 .. 20,000                                        0 .. 20,000     0 .. 20,000
# average_forever            0                                                  0               0
# average_2weeks             0                                                  0               0
# median_forever             0                                                  0               0
# median_2weeks              0                                                  0               0
# price                     99                                                  0               0
# initialprice              99                                                  0               0
# discount                   0                                                  0               0
#
#                       706550                          587030  \
# appid                 706550                          587030
# name                    Kaya  Bunker Busters Steamworks Test
# developer              KirUn
# publisher              KirUn
# score_rank
# positive                   0                               0
# negative                   0                               0
# userscore                  0                               0
# owners           0 .. 20,000                     0 .. 20,000
# average_forever            0                               0
# average_2weeks             0                               0
# median_forever             0                               0
# median_2weeks              0                               0
# price                      0                            None
# initialprice               0                            None
# discount                   0                            None
#
#                                                 46470         781150  \
# appid                                           46470         781150
# name             Grotesque Tactics: Evil Heroes - Dev      Gene Rain
# developer                                              Deeli network
# publisher                                              Deeli network
# score_rank
# positive                                            0              0
# negative                                            0              0
# userscore                                           0              0
# owners                                    0 .. 20,000    0 .. 20,000
# average_forever                                     0              0
# average_2weeks                                      0              0
# median_forever                                      0              0
# median_2weeks                                       0              0
# price                                               0              0
# initialprice                                        0              0
# discount                                            0              0
#
#                                                  874630            788200
# appid                                            874630            788200
# name             M.A.D. Cliff - All Quiet On The Bridge  The Little Slime
# developer                                  Flying Whale          SudoTilt
# publisher                                  Flying Whale          SudoTilt
# score_rank
# positive                                              0                 3
# negative                                              0                 2
# userscore                                             0                 0
# owners                                      0 .. 20,000       0 .. 20,000
# average_forever                                       0                 0
# average_2weeks                                        0                 0
# median_forever                                        0                 0
# median_2weeks                                         0                 0
# price                                               599               699
# initialprice                                        599               699
# discount                                              0                 0
#
# [16 rows x 35935 columns]

# %%
# checking the shape 
df.shape
# Out:
# (16, 35935)

# %%
# transposing the data frame to convert the columns into rows
df = df.T

# %%
# checking the updated data frame
df.head()
# Out:
#          appid                              name                         developer  \
# 570        570                            Dota 2                             Valve
# 730        730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 578080  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 440        440                   Team Fortress 2                             Valve
# 304930  304930                          Unturned             Smartly Dressed Games
#
#                     publisher score_rank positive negative userscore                      owners  \
# 570                     Valve             1097301   194384         0  100,000,000 .. 200,000,000
# 730                     Valve             3837538   533489         0  100,000,000 .. 200,000,000
# 578080       PUBG Corporation              782126   665184         0    20,000,000 .. 50,000,000
# 440                     Valve              627753    39210         0    20,000,000 .. 50,000,000
# 304930  Smartly Dressed Games              349381    34828         0    20,000,000 .. 50,000,000
#
#        average_forever average_2weeks median_forever median_2weeks price initialprice discount
# 570              31658           1716           1312           823     0            0        0
# 730              26845           1263           8022           421     0            0        0
# 578080           23329            766          11603           240  2999         2999        0
# 440              10329           1598            426           513     0            0        0
# 304930            2817            789            344           816     0            0        0

# %%
# checking shape
df.shape
# Out:
# (35935, 16)

# %%
# checking for any null values in this data set
df.isnull().any()
# Out:
# appid              False
# name               False
# developer          False
# publisher          False
# score_rank         False
# positive           False
# negative           False
# userscore          False
# owners             False
# average_forever    False
# average_2weeks     False
# median_forever     False
# median_2weeks      False
# price               True
# initialprice        True
# discount            True
# dtype: bool

# %%
# reseting index so that it doesnt show the appid twice
df.reset_index(drop=True, inplace=True)

# %%
# displaying the data frame to check the changes
df.head()
# Out:
#     appid                              name                         developer  \
# 0     570                            Dota 2                             Valve
# 1     730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 3     440                   Team Fortress 2                             Valve
# 4  304930                          Unturned             Smartly Dressed Games
#
#                publisher score_rank positive negative userscore                      owners  \
# 0                  Valve             1097301   194384         0  100,000,000 .. 200,000,000
# 1                  Valve             3837538   533489         0  100,000,000 .. 200,000,000
# 2       PUBG Corporation              782126   665184         0    20,000,000 .. 50,000,000
# 3                  Valve              627753    39210         0    20,000,000 .. 50,000,000
# 4  Smartly Dressed Games              349381    34828         0    20,000,000 .. 50,000,000
#
#   average_forever average_2weeks median_forever median_2weeks price initialprice discount
# 0           31658           1716           1312           823     0            0        0
# 1           26845           1263           8022           421     0            0        0
# 2           23329            766          11603           240  2999         2999        0
# 3           10329           1598            426           513     0            0        0
# 4            2817            789            344           816     0            0        0

# %% [markdown]
# # Importing data frames

# %% [markdown]
# ### Data frame with games information

# %% [markdown]
# This data was sourced from the steamspy api, and contains all of steams games, and their relevant game information such as scores, developers, price and other such information.

# %% [markdown]
# <b>Variables:</b>
# <li><b>'appid':</b> unique ids of each game
# <li><b>'name':</b> name of the game
# <li><b>'developer':</b> developer of the game
# <li><b>'publisher':</b> publisher of the game
# <li><b>'score_rank':</b> publisher of the game
# <li><b>'positive':</b> postive scores
# <li><b>'negative':</b> negative scores
# <li><b>'userscore':</b> amount of users that scores
# <li><b>'owners':</b> number of people that bought the game
# <li><b>'average_forever':</b> entire average play time
# <li><b>'average_2weeks':</b> average play time over 2 weeks
# <li><b>'median_forever':</b> entire median play time
# <li><b>'median_2weeks':</b> median play time over 2 weeks
# <li><b>'price':</b> price of game
# <li><b>'initialprice':</b> inital price of game
# <li><b>'discount':</b> discount price

# %%
# inital data frame with the scraped data from steamspy
df.head()
# Out:
#     appid                              name                         developer  \
# 0     570                            Dota 2                             Valve
# 1     730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 3     440                   Team Fortress 2                             Valve
# 4  304930                          Unturned             Smartly Dressed Games
#
#                publisher score_rank positive negative userscore                      owners  \
# 0                  Valve             1097301   194384         0  100,000,000 .. 200,000,000
# 1                  Valve             3837538   533489         0  100,000,000 .. 200,000,000
# 2       PUBG Corporation              782126   665184         0    20,000,000 .. 50,000,000
# 3                  Valve              627753    39210         0    20,000,000 .. 50,000,000
# 4  Smartly Dressed Games              349381    34828         0    20,000,000 .. 50,000,000
#
#   average_forever average_2weeks median_forever median_2weeks price initialprice discount
# 0           31658           1716           1312           823     0            0        0
# 1           26845           1263           8022           421     0            0        0
# 2           23329            766          11603           240  2999         2999        0
# 3           10329           1598            426           513     0            0        0
# 4            2817            789            344           816     0            0        0

# %%
# renaming the data frame
game_info = df

# %% [markdown]
# ### Data frame with player purchase/play information

# %% [markdown]
# this data set was sourced from kaggle: https://www.kaggle.com/tamber/steam-video-games

# %% [markdown]
# <b>Variables:</b>
# <li><b>'151603712':</b> unique ids of each game
# <li><b>'The Elder Scrolls V Skyrim':</b> name of the game
# <li><b>'purchase':</b> purchased or played
# <li><b>'1.0':</b> hours of play, value is 1.0 if purchased
# <li><b>'0':</b> 0 (this appears to be an column full of zeros and will be removed later)

# %%
# player purchase/play details
df_2 = pd.read_csv('steam-200k.csv')
df_2.head()
# Out:
#    151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 0  151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 1  151603712                   Fallout 4  purchase    1.0  0
# 2  151603712                   Fallout 4      play   87.0  0
# 3  151603712                       Spore  purchase    1.0  0
# 4  151603712                       Spore      play   14.9  0

# %% [markdown]
# The columns appear to be a row it self, so i will be bringing that information down and providing the columns with proper names.

# %%
# re importing the data set to bring down the column headers as a row
df_2 = pd.read_csv('steam-200k.csv', header=None)
df_2.head()
# Out:
#            0                           1         2      3  4
# 0  151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 1  151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 2  151603712                   Fallout 4  purchase    1.0  0
# 3  151603712                   Fallout 4      play   87.0  0
# 4  151603712                       Spore  purchase    1.0  0

# %%
# renaming the data frame
purchase_play_info = df_2

# %% [markdown]
# ### Data frame with games descriptions

# %% [markdown]
# this data set was sourced from kaggle: https://www.kaggle.com/nikdavis/steam-store-games

# %% [markdown]
# <b>Variables:</b>
# <li><b>'steam_appid':</b> unique ids of each game
# <li><b>'detailed_description':</b> detailed description of the game
# <li><b>'about_the_game':</b> information about the game
# <li><b>'short_description':</b> short description of the game

# %%
# game descriptions
df_3 = pd.read_csv('steam_description_data.csv')
df_3.head()
# Out:
#    steam_appid                               detailed_description  \
# 0           10  Play the world's number 1 online action game. ...
# 1           20  One of the most popular online action games of...
# 2           30  Enlist in an intense brand of Axis vs. Allied ...
# 3           40  Enjoy fast-paced multiplayer gaming with Death...
# 4           50  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...

# %%
# renaming the data frame
game_desc = df_3

# %% [markdown]
# ### Data frame with more games information

# %% [markdown]
# this data set was sourced from kaggle: https://www.kaggle.com/nikdavis/steam-store-games

# %% [markdown]
# <b>Variables:</b>
# <li><b>'appid':</b> unique ids of each game
# <li><b>'name':</b> name of the game
# <li><b>'release_date':</b> game release date
# <li><b>'english':</b> returns if the game is english or not
# <li><b>'developer':</b> developer of the game
# <li><b>'publisher':</b> publisher of the game
# <li><b>'platforms':</b> compatible platforms
# <li><b>'required_age':</b> minimum age requirements of game
# <li><b>'categories':</b> game categories
# <li><b>'genres':</b> game genres
# <li><b>'steamspy_tags':</b> tags of game
# <li><b>'achievements':</b> game achievements completed
# <li><b>'positive_ratings':</b> postive ratings of the game
# <li><b>'negative_ratings':</b> negative ratings of the game
# <li><b>'average_playtime':</b> average playtime
# <li><b>'median_playtime':</b> median playtime
# <li><b>'owners':</b> amount of people who purpchased the game
# <li><b>'price':</b> price

# %%
# information
df_4 = pd.read_csv('steam.csv')
df_4.head()
# Out:
#    appid                       name release_date  english         developer publisher  \
# 0     10             Counter-Strike   2000-11-01        1             Valve     Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve     Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve     Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve     Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software     Valve
#
#            platforms  required_age                                         categories  genres  \
# 0  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2  windows;mac;linux             0              Multi-player;Valve Anti-Cheat enabled  Action
# 3  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  windows;mac;linux             0  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 0        Action;FPS;Multiplayer             0            124534              3339
# 1        Action;FPS;Multiplayer             0              3318               633
# 2  FPS;World War II;Multiplayer             0              3416               398
# 3        Action;FPS;Multiplayer             0              1273               267
# 4             FPS;Action;Sci-fi             0              5250               288
#
#    average_playtime  median_playtime             owners  price
# 0             17612              317  10000000-20000000   7.19
# 1               277               62   5000000-10000000   3.99
# 2               187               34   5000000-10000000   3.99
# 3               258              184   5000000-10000000   3.99
# 4               624              415   5000000-10000000   3.99

# %%
# renaming the data frame
game_info_2 = df_4

# %% [markdown]
# # Merging the data frames

# %%
# displaying data frame with steamspy data
game_info.head()
# Out:
#     appid                              name                         developer  \
# 0     570                            Dota 2                             Valve
# 1     730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 3     440                   Team Fortress 2                             Valve
# 4  304930                          Unturned             Smartly Dressed Games
#
#                publisher score_rank positive negative userscore                      owners  \
# 0                  Valve             1097301   194384         0  100,000,000 .. 200,000,000
# 1                  Valve             3837538   533489         0  100,000,000 .. 200,000,000
# 2       PUBG Corporation              782126   665184         0    20,000,000 .. 50,000,000
# 3                  Valve              627753    39210         0    20,000,000 .. 50,000,000
# 4  Smartly Dressed Games              349381    34828         0    20,000,000 .. 50,000,000
#
#   average_forever average_2weeks median_forever median_2weeks price initialprice discount
# 0           31658           1716           1312           823     0            0        0
# 1           26845           1263           8022           421     0            0        0
# 2           23329            766          11603           240  2999         2999        0
# 3           10329           1598            426           513     0            0        0
# 4            2817            789            344           816     0            0        0

# %%
# checking shape
game_info.shape
# Out:
# (35935, 16)

# %%
# checking data of the data frame containg game information
game_info_2.head()
# Out:
#    appid                       name release_date  english         developer publisher  \
# 0     10             Counter-Strike   2000-11-01        1             Valve     Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve     Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve     Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve     Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software     Valve
#
#            platforms  required_age                                         categories  genres  \
# 0  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2  windows;mac;linux             0              Multi-player;Valve Anti-Cheat enabled  Action
# 3  windows;mac;linux             0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  windows;mac;linux             0  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 0        Action;FPS;Multiplayer             0            124534              3339
# 1        Action;FPS;Multiplayer             0              3318               633
# 2  FPS;World War II;Multiplayer             0              3416               398
# 3        Action;FPS;Multiplayer             0              1273               267
# 4             FPS;Action;Sci-fi             0              5250               288
#
#    average_playtime  median_playtime             owners  price
# 0             17612              317  10000000-20000000   7.19
# 1               277               62   5000000-10000000   3.99
# 2               187               34   5000000-10000000   3.99
# 3               258              184   5000000-10000000   3.99
# 4               624              415   5000000-10000000   3.99

# %%
# checking shape
game_info_2.shape
# Out:
# (27075, 18)

# %%
# checking columns
game_info_2.columns
# Out:
# Index(['appid', 'name', 'release_date', 'english', 'developer', 'publisher', 'platforms',
#        'required_age', 'categories', 'genres', 'steamspy_tags', 'achievements', 'positive_ratings',
#        'negative_ratings', 'average_playtime', 'median_playtime', 'owners', 'price'],
#       dtype='object')

# %%
# checking columns
game_info.columns
# Out:
# Index(['appid', 'name', 'developer', 'publisher', 'score_rank', 'positive', 'negative',
#        'userscore', 'owners', 'average_forever', 'average_2weeks', 'median_forever',
#        'median_2weeks', 'price', 'initialprice', 'discount'],
#       dtype='object')

# %% [markdown]
# As both of these data frame contain all steam games, along with other relevant game information, i will be combining these two data sets to form one data set will all of game information

# %% [markdown]
# I will be now checking if both of these data frames are correctly assigned to their own unique app id. If the app id and their corresponding game match then i will be merging the two data frames based on the app id column.

# %%
# checking a specific row
game_info[game_info['name'] == 'Dota 2']
# Out:
#   appid    name developer publisher score_rank positive negative userscore  \
# 0   570  Dota 2     Valve     Valve             1097301   194384         0
#
#                        owners average_forever average_2weeks median_forever median_2weeks price  \
# 0  100,000,000 .. 200,000,000           31658           1716           1312           823     0
#
#   initialprice discount
# 0            0        0

# %%
# checking a specific row
game_info_2[game_info_2.name == 'Dota 2']
# Out:
#     appid    name release_date  english developer publisher          platforms  required_age  \
# 22    570  Dota 2   2013-07-09        1     Valve     Valve  windows;mac;linux             0
#
#                                            categories                        genres  \
# 22  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
#
#                  steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 22  Free to Play;MOBA;Strategy             0            863507            142079
#
#     average_playtime  median_playtime               owners  price
# 22             23944              801  100000000-200000000    0.0

# %% [markdown]
# As the app ids and the name of the game match up in both of the data frames these will be merged based on the game id.

# %%
# dropping unessasary columns and columns that appear in both data frames
game_info.drop(['price', 'initialprice', 'discount', 'average_2weeks', 'median_2weeks', 'owners'], axis=1, inplace=True)

# %%
# dropping unessasary columns
game_info_2.drop(['name', 'developer', 'publisher'], axis=1, inplace=True)

# %%
# merging the data frames based on the appid
game_info = pd.DataFrame.merge(game_info, game_info_2,on='appid')

# %%
# checking the merged data frame will all of the games information
game_info.head()
# Out:
#     appid                              name                         developer  \
# 0     570                            Dota 2                             Valve
# 1     730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 3     440                   Team Fortress 2                             Valve
# 4  304930                          Unturned             Smartly Dressed Games
#
#                publisher score_rank positive negative userscore average_forever median_forever  \
# 0                  Valve             1097301   194384         0           31658           1312
# 1                  Valve             3837538   533489         0           26845           8022
# 2       PUBG Corporation              782126   665184         0           23329          11603
# 3                  Valve              627753    39210         0           10329            426
# 4  Smartly Dressed Games              349381    34828         0            2817            344
#
#   release_date  english          platforms  required_age  \
# 0   2013-07-09        1  windows;mac;linux             0
# 1   2012-08-21        1  windows;mac;linux             0
# 2   2017-12-21        1            windows             0
# 3   2007-10-10        1  windows;mac;linux             0
# 4   2017-07-07        1  windows;mac;linux             0
#
#                                           categories                                      genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...                Action;Free to Play;Strategy
# 1  Multi-player;Steam Achievements;Full controlle...                         Action;Free to Play
# 2             Multi-player;Online Multi-Player;Stats      Action;Adventure;Massively Multiplayer
# 3  Multi-player;Cross-Platform Multiplayer;Steam ...                         Action;Free to Play
# 4  Single-player;Online Multi-Player;Online Co-op...  Action;Adventure;Casual;Free to Play;Indie
#
#                    steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 0     Free to Play;MOBA;Strategy             0            863507            142079
# 1        FPS;Multiplayer;Shooter           167           2644404            402313
# 2   Survival;Shooter;Multiplayer            37            496184            487076
# 3   Free to Play;Multiplayer;FPS           520            515879             34036
# 4  Free to Play;Survival;Zombies            46            292574             31482
#
#    average_playtime  median_playtime               owners  price
# 0             23944              801  100000000-200000000   0.00
# 1             22494             6502   50000000-100000000   0.00
# 2             22938            12434   50000000-100000000  26.99
# 3              8495              623    20000000-50000000   0.00
# 4              3248              413    20000000-50000000   0.00

# %%
# checking the shape
game_info.shape
# Out:
# (25974, 24)

# %%
# checking all of the columns
game_info.columns
# Out:
# Index(['appid', 'name', 'developer', 'publisher', 'score_rank', 'positive', 'negative',
#        'userscore', 'average_forever', 'median_forever', 'release_date', 'english', 'platforms',
#        'required_age', 'categories', 'genres', 'steamspy_tags', 'achievements', 'positive_ratings',
#        'negative_ratings', 'average_playtime', 'median_playtime', 'owners', 'price'],
#       dtype='object')

# %% [markdown]
# Adding to this newly created data frame i think that it would be useful to include the game descriptions of each of these video games.

# %%
# checking the data frame containing all game descriptions
game_desc
# Out:
#        steam_appid                               detailed_description  \
# 0               10  Play the world's number 1 online action game. ...
# 1               20  One of the most popular online action games of...
# 2               30  Enlist in an intense brand of Axis vs. Allied ...
# 3               40  Enjoy fast-paced multiplayer gaming with Death...
# 4               50  Return to the Black Mesa Research Facility as ...
# ...            ...                                                ...
# 27329      1065230  <img src="https://steamcdn-a.akamaihd.net/stea...
# 27330      1065570  Have you ever been so lonely that no one but y...
# 27331      1065650  <strong>Super Star Blast </strong>is a space b...
# 27332      1066700  Pursue a snow-white deer through an enchanted ...
# 27333      1069460  A portal has opened and dark magic is pouring ...
#
#                                           about_the_game  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 27329  <img src="https://steamcdn-a.akamaihd.net/stea...
# 27330  Have you ever been so lonely that no one but y...
# 27331  <strong>Super Star Blast </strong>is a space b...
# 27332  Pursue a snow-white deer through an enchanted ...
# 27333  A portal has opened and dark magic is pouring ...
#
#                                        short_description
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 27329  The Room of Pandora is a third-person interact...
# 27330  Cyber Gun is a hardcore first-person shooter w...
# 27331  Super Star Blast is a space based game with ch...
# 27332  Pursue a snow-white deer through an enchanted ...
# 27333  A portal has opened and dark magic is pouring ...
#
# [27334 rows x 4 columns]

# %%
# renaming steam_appid to appid in order to merge the data frames together
game_desc.rename(columns={'steam_appid': 'appid'}, inplace=True)

# %%
# merging the game_info data frame to game_desc data frame
game_info = pd.DataFrame.merge(game_info, game_desc,on='appid')

# %%
# displaying the updated data frame
game_info.head()
# Out:
#     appid                              name                         developer  \
# 0     570                            Dota 2                             Valve
# 1     730  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS                  PUBG Corporation
# 3     440                   Team Fortress 2                             Valve
# 4  304930                          Unturned             Smartly Dressed Games
#
#                publisher score_rank positive negative userscore average_forever median_forever  \
# 0                  Valve             1097301   194384         0           31658           1312
# 1                  Valve             3837538   533489         0           26845           8022
# 2       PUBG Corporation              782126   665184         0           23329          11603
# 3                  Valve              627753    39210         0           10329            426
# 4  Smartly Dressed Games              349381    34828         0            2817            344
#
#   release_date  english          platforms  required_age  \
# 0   2013-07-09        1  windows;mac;linux             0
# 1   2012-08-21        1  windows;mac;linux             0
# 2   2017-12-21        1            windows             0
# 3   2007-10-10        1  windows;mac;linux             0
# 4   2017-07-07        1  windows;mac;linux             0
#
#                                           categories                                      genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...                Action;Free to Play;Strategy
# 1  Multi-player;Steam Achievements;Full controlle...                         Action;Free to Play
# 2             Multi-player;Online Multi-Player;Stats      Action;Adventure;Massively Multiplayer
# 3  Multi-player;Cross-Platform Multiplayer;Steam ...                         Action;Free to Play
# 4  Single-player;Online Multi-Player;Online Co-op...  Action;Adventure;Casual;Free to Play;Indie
#
#                    steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 0     Free to Play;MOBA;Strategy             0            863507            142079
# 1        FPS;Multiplayer;Shooter           167           2644404            402313
# 2   Survival;Shooter;Multiplayer            37            496184            487076
# 3   Free to Play;Multiplayer;FPS           520            515879             34036
# 4  Free to Play;Survival;Zombies            46            292574             31482
#
#    average_playtime  median_playtime               owners  price  \
# 0             23944              801  100000000-200000000   0.00
# 1             22494             6502   50000000-100000000   0.00
# 2             22938            12434   50000000-100000000  26.99
# 3              8495              623    20000000-50000000   0.00
# 4              3248              413    20000000-50000000   0.00
#
#                                 detailed_description  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  Counter-Strike: Global Offensive (CS: GO) expa...
# 2  <strong>PLAYERUNKNOWN'S BATTLEGROUNDS</strong>...
# 3  <h1>The Jungle Inferno Update</h1><p><a href="...
# 4  <img src="https://steamcdn-a.akamaihd.net/stea...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  Counter-Strike: Global Offensive (CS: GO) expa...
# 2  <strong>PLAYERUNKNOWN'S BATTLEGROUNDS</strong>...
# 3  <p><strong>"The most fun you can have online"<...
# 4  <img src="https://steamcdn-a.akamaihd.net/stea...
#
#                                    short_description
# 0  Every day, millions of players worldwide enter...
# 1  Counter-Strike: Global Offensive (CS: GO) expa...
# 2  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 3  Nine distinct classes provide a broad range of...
# 4  You're a survivor in the zombie infested ruins...

# %% [markdown]
# Using the updated game_info data frame i will be adding it to the player information data frame so that

# %%
# checking the player information data frame
purchase_play_info
# Out:
#                 0                           1         2      3  4
# 0       151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 1       151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 2       151603712                   Fallout 4  purchase    1.0  0
# 3       151603712                   Fallout 4      play   87.0  0
# 4       151603712                       Spore  purchase    1.0  0
# ...           ...                         ...       ...    ... ..
# 199995  128470551                 Titan Souls      play    1.5  0
# 199996  128470551  Grand Theft Auto Vice City  purchase    1.0  0
# 199997  128470551  Grand Theft Auto Vice City      play    1.5  0
# 199998  128470551                        RUSH  purchase    1.0  0
# 199999  128470551                        RUSH      play    1.4  0
#
# [200000 rows x 5 columns]

# %%
# renaming columns
purchase_play_info.rename(columns={0: 'id', 1: 'name', 2: 'purchase',
                     3: 'hours_of_play'}, inplace=True)

# %%
# displaying changes
purchase_play_info.head()
# Out:
#           id                        name  purchase  hours_of_play  4
# 0  151603712  The Elder Scrolls V Skyrim  purchase            1.0  0
# 1  151603712  The Elder Scrolls V Skyrim      play          273.0  0
# 2  151603712                   Fallout 4  purchase            1.0  0
# 3  151603712                   Fallout 4      play           87.0  0
# 4  151603712                       Spore  purchase            1.0  0

# %%
# checking column names
purchase_play_info.columns
# Out:
# Index(['id', 'name', 'purchase', 'hours_of_play', 4], dtype='object')

# %%
# checking what information column 4 contains within it
purchase_play_info[4].unique()
# Out:
# array([0], dtype=int64)

# %%
# as column 4 conains soley zeros, this column will be removed
del purchase_play_info[4]

# %%
# displaying the changed data frame
purchase_play_info.head()
# Out:
#           id                        name  purchase  hours_of_play
# 0  151603712  The Elder Scrolls V Skyrim  purchase            1.0
# 1  151603712  The Elder Scrolls V Skyrim      play          273.0
# 2  151603712                   Fallout 4  purchase            1.0
# 3  151603712                   Fallout 4      play           87.0
# 4  151603712                       Spore  purchase            1.0

# %%
# checking player information based on a specific game
purchase_play_info[purchase_play_info.name == 'Dota 2']
# Out:
#                id    name  purchase  hours_of_play
# 42      151603712  Dota 2  purchase            1.0
# 43      151603712  Dota 2      play            0.5
# 66      187131847  Dota 2  purchase            1.0
# 67      187131847  Dota 2      play            2.3
# 855     176410694  Dota 2  purchase            1.0
# ...           ...     ...       ...            ...
# 199897   99096740  Dota 2      play         1704.0
# 199948  176449171  Dota 2  purchase            1.0
# 199949  176449171  Dota 2      play         1310.0
# 199960  221315846  Dota 2  purchase            1.0
# 199961  221315846  Dota 2      play            9.0
#
# [9682 rows x 4 columns]

# %%
# merging the two data frames into one based on the name of the game column
df_final = pd.DataFrame.merge(game_info, purchase_play_info, on='name')

# %%
# previewing the final data frame
df_final.head()
# Out:
#   appid    name developer publisher score_rank positive negative userscore average_forever  \
# 0   570  Dota 2     Valve     Valve             1097301   194384         0           31658
# 1   570  Dota 2     Valve     Valve             1097301   194384         0           31658
# 2   570  Dota 2     Valve     Valve             1097301   194384         0           31658
# 3   570  Dota 2     Valve     Valve             1097301   194384         0           31658
# 4   570  Dota 2     Valve     Valve             1097301   194384         0           31658
#
#   median_forever release_date  english          platforms  required_age  \
# 0           1312   2013-07-09        1  windows;mac;linux             0
# 1           1312   2013-07-09        1  windows;mac;linux             0
# 2           1312   2013-07-09        1  windows;mac;linux             0
# 3           1312   2013-07-09        1  windows;mac;linux             0
# 4           1312   2013-07-09        1  windows;mac;linux             0
#
#                                           categories                        genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 1  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 2  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 3  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 4  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
#
#                 steamspy_tags  achievements  positive_ratings  negative_ratings  average_playtime  \
# 0  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 1  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 2  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 3  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 4  Free to Play;MOBA;Strategy             0            863507            142079             23944
#
#    median_playtime               owners  price                               detailed_description  \
# 0              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 1              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 2              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 3              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 4              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  <strong>The most-played game on Steam.</strong...
# 2  <strong>The most-played game on Steam.</strong...
# 3  <strong>The most-played game on Steam.</strong...
# 4  <strong>The most-played game on Steam.</strong...
#
#                                    short_description         id  purchase  hours_of_play
# 0  Every day, millions of players worldwide enter...  151603712  purchase            1.0
# 1  Every day, millions of players worldwide enter...  151603712      play            0.5
# 2  Every day, millions of players worldwide enter...  187131847  purchase            1.0
# 3  Every day, millions of players worldwide enter...  187131847      play            2.3
# 4  Every day, millions of players worldwide enter...  176410694  purchase            1.0

# %%
# checking its shape
df_final.shape
# Out:
# (99632, 30)

# %% [markdown]
# # DATA CLEANING

# %%
# renaming the final data frame
steam = df_final

# %% [markdown]
# ### Checking for null values

# %%
# detecting nan values in dataframe
steam.isnull().values.any()
# Out:
# False

# %%
# locating where the nan values exist and the amount of nan values for each columns
steam.isnull().sum()
# Out:
# appid                   0
# name                    0
# developer               0
# publisher               0
# score_rank              0
# positive                0
# negative                0
# userscore               0
# average_forever         0
# median_forever          0
# release_date            0
# english                 0
# platforms               0
# required_age            0
# categories              0
# genres                  0
# steamspy_tags           0
# achievements            0
# positive_ratings        0
# negative_ratings        0
# average_playtime        0
# median_playtime         0
# owners                  0
# price                   0
# detailed_description    0
# about_the_game          0
# short_description       0
# id                      0
# purchase                0
# hours_of_play           0
# dtype: int64

# %% [markdown]
# From these results there have been no null values found.

# %%
# checking the shape of the data frame
steam.shape
# Out:
# (99632, 30)

# %%
# checking the data types
steam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99632 entries, 0 to 99631
# Data columns (total 30 columns):
# appid                   99632 non-null object
# name                    99632 non-null object
# developer               99632 non-null object
# publisher               99632 non-null object
# score_rank              99632 non-null object
# positive                99632 non-null object
# negative                99632 non-null object
# userscore               99632 non-null object
# average_forever         99632 non-null object
# median_forever          99632 non-null object
# release_date            99632 non-null object
# english                 99632 non-null int64
# platforms               99632 non-null object
# required_age            99632 non-null int64
# categories              99632 non-null object
# genres                  99632 non-null object
# steamspy_tags           99632 non-null object
# achievements            99632 non-null int64
# positive_ratings        99632 non-null int64
# negative_ratings        99632 non-null int64
# average_playtime        99632 non-null int64
# median_playtime         99632 non-null int64
# owners                  99632 non-null object
# price                   99632 non-null float64
# detailed_description    99632 non-null object
# about_the_game          99632 non-null object
# short_description       99632 non-null object
# id                      99632 non-null int64
# purchase                99632 non-null object
# hours_of_play           99632 non-null float64
# dtypes: float64(2), int64(8), object(20)
# memory usage: 23.6+ MB

# %%
# checking min, max and other relevant information
steam.describe()
# Out:
#             english  required_age  achievements  positive_ratings  negative_ratings  \
# count  99632.000000  99632.000000  99632.000000      99632.000000      99632.000000
# mean       0.999689      2.189136     73.792958     158305.744098      21695.036173
# std        0.017637      5.763453    155.461837     264246.799053      42467.627565
# min        0.000000      0.000000      0.000000          0.000000          0.000000
# 25%        1.000000      0.000000      0.000000       3700.000000        657.500000
# 50%        1.000000      0.000000     29.000000      27755.000000       2609.000000
# 75%        1.000000      0.000000     67.000000     144595.000000      16433.000000
# max        1.000000     18.000000   1746.000000     863507.000000     142079.000000
#
#        average_playtime  median_playtime         price            id  hours_of_play
# count      99632.000000     99632.000000  99632.000000  9.963200e+04   99632.000000
# mean        4445.184629       589.851333      6.667732  1.135632e+08      21.761117
# std         7271.300668      1439.313553      7.554852  7.539969e+07     172.208015
# min            0.000000         0.000000      0.000000  5.250000e+03       0.100000
# 25%          258.000000       150.000000      0.000000  5.108578e+07       1.000000
# 50%          949.000000       362.000000      6.990000  1.012121e+08       1.000000
# 75%         4760.000000       801.000000      9.990000  1.668631e+08       2.000000
# max        95242.000000    190445.000000     69.990000  3.099031e+08   11754.000000

# %%
# converting release_date to date time format
steam['release_date'] = pd.to_datetime(steam['release_date'])

# %%
# changing the values that if a player has purchased a game their hour of play is 0, as they have not played it yet.
steam.loc[(steam['purchase'] == 'purchase') & (steam['hours_of_play'] == 1.0), 'hours_of_play'] = 0

# %%
# displaying data frame
steam.head()
# Out:
#   appid    name developer publisher score_rank positive negative userscore average_forever  \
# 0   570  Dota 2     Valve     Valve             1097301   194384         0           31658
# 1   570  Dota 2     Valve     Valve             1097301   194384         0           31658
# 2   570  Dota 2     Valve     Valve             1097301   194384         0           31658
# 3   570  Dota 2     Valve     Valve             1097301   194384         0           31658
# 4   570  Dota 2     Valve     Valve             1097301   194384         0           31658
#
#   median_forever release_date  english          platforms  required_age  \
# 0           1312   2013-07-09        1  windows;mac;linux             0
# 1           1312   2013-07-09        1  windows;mac;linux             0
# 2           1312   2013-07-09        1  windows;mac;linux             0
# 3           1312   2013-07-09        1  windows;mac;linux             0
# 4           1312   2013-07-09        1  windows;mac;linux             0
#
#                                           categories                        genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 1  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 2  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 3  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 4  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
#
#                 steamspy_tags  achievements  positive_ratings  negative_ratings  average_playtime  \
# 0  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 1  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 2  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 3  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 4  Free to Play;MOBA;Strategy             0            863507            142079             23944
#
#    median_playtime               owners  price                               detailed_description  \
# 0              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 1              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 2              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 3              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
# 4              801  100000000-200000000    0.0  <strong>The most-played game on Steam.</strong...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  <strong>The most-played game on Steam.</strong...
# 2  <strong>The most-played game on Steam.</strong...
# 3  <strong>The most-played game on Steam.</strong...
# 4  <strong>The most-played game on Steam.</strong...
#
#                                    short_description         id  purchase  hours_of_play
# 0  Every day, millions of players worldwide enter...  151603712  purchase            0.0
# 1  Every day, millions of players worldwide enter...  151603712      play            0.5
# 2  Every day, millions of players worldwide enter...  187131847  purchase            0.0
# 3  Every day, millions of players worldwide enter...  187131847      play            2.3
# 4  Every day, millions of players worldwide enter...  176410694  purchase            0.0

# %%
# checking the current arrangement of the columns
steam.columns
# Out:
# Index(['appid', 'name', 'developer', 'publisher', 'score_rank', 'positive', 'negative',
#        'userscore', 'average_forever', 'median_forever', 'release_date', 'english', 'platforms',
#        'required_age', 'categories', 'genres', 'steamspy_tags', 'achievements', 'positive_ratings',
#        'negative_ratings', 'average_playtime', 'median_playtime', 'owners', 'price',
#        'detailed_description', 'about_the_game', 'short_description', 'id', 'purchase',
#        'hours_of_play'],
#       dtype='object')

# %%
# changing the arrangment of the columns
steam = steam[['id', 'appid', 'name', 'purchase', 'hours_of_play', 'developer',
       'publisher', 'score_rank', 'positive', 'negative', 'userscore', 'release_date', 'english',
       'platforms', 'required_age', 'categories', 'genres', 'steamspy_tags', 'achievements',
       'positive_ratings', 'negative_ratings', 'average_playtime', 'average_forever',
       'median_playtime', 'median_forever', 'owners', 'detailed_description', 'about_the_game',
       'short_description', 'price']]

# %%
# checking the changes made
steam.columns
# Out:
# Index(['id', 'appid', 'name', 'purchase', 'hours_of_play', 'developer', 'publisher', 'score_rank',
#        'positive', 'negative', 'userscore', 'release_date', 'english', 'platforms', 'required_age',
#        'categories', 'genres', 'steamspy_tags', 'achievements', 'positive_ratings',
#        'negative_ratings', 'average_playtime', 'average_forever', 'median_playtime',
#        'median_forever', 'owners', 'detailed_description', 'about_the_game', 'short_description',
#        'price'],
#       dtype='object')

# %%
# displaying the data frame to check the changes made
steam.head()
# Out:
#           id appid    name  purchase  hours_of_play developer publisher score_rank positive  \
# 0  151603712   570  Dota 2  purchase            0.0     Valve     Valve             1097301
# 1  151603712   570  Dota 2      play            0.5     Valve     Valve             1097301
# 2  187131847   570  Dota 2  purchase            0.0     Valve     Valve             1097301
# 3  187131847   570  Dota 2      play            2.3     Valve     Valve             1097301
# 4  176410694   570  Dota 2  purchase            0.0     Valve     Valve             1097301
#
#   negative userscore release_date  english          platforms  required_age  \
# 0   194384         0   2013-07-09        1  windows;mac;linux             0
# 1   194384         0   2013-07-09        1  windows;mac;linux             0
# 2   194384         0   2013-07-09        1  windows;mac;linux             0
# 3   194384         0   2013-07-09        1  windows;mac;linux             0
# 4   194384         0   2013-07-09        1  windows;mac;linux             0
#
#                                           categories                        genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 1  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 2  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 3  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 4  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
#
#                 steamspy_tags  achievements  positive_ratings  negative_ratings  average_playtime  \
# 0  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 1  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 2  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 3  Free to Play;MOBA;Strategy             0            863507            142079             23944
# 4  Free to Play;MOBA;Strategy             0            863507            142079             23944
#
#   average_forever  median_playtime median_forever               owners  \
# 0           31658              801           1312  100000000-200000000
# 1           31658              801           1312  100000000-200000000
# 2           31658              801           1312  100000000-200000000
# 3           31658              801           1312  100000000-200000000
# 4           31658              801           1312  100000000-200000000
#
#                                 detailed_description  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  <strong>The most-played game on Steam.</strong...
# 2  <strong>The most-played game on Steam.</strong...
# 3  <strong>The most-played game on Steam.</strong...
# 4  <strong>The most-played game on Steam.</strong...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  <strong>The most-played game on Steam.</strong...
# 2  <strong>The most-played game on Steam.</strong...
# 3  <strong>The most-played game on Steam.</strong...
# 4  <strong>The most-played game on Steam.</strong...
#
#                                    short_description  price
# 0  Every day, millions of players worldwide enter...    0.0
# 1  Every day, millions of players worldwide enter...    0.0
# 2  Every day, millions of players worldwide enter...    0.0
# 3  Every day, millions of players worldwide enter...    0.0
# 4  Every day, millions of players worldwide enter...    0.0

# %%
# checking the data types
steam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99632 entries, 0 to 99631
# Data columns (total 30 columns):
# id                      99632 non-null int64
# appid                   99632 non-null object
# name                    99632 non-null object
# purchase                99632 non-null object
# hours_of_play           99632 non-null float64
# developer               99632 non-null object
# publisher               99632 non-null object
# score_rank              99632 non-null object
# positive                99632 non-null object
# negative                99632 non-null object
# userscore               99632 non-null object
# release_date            99632 non-null datetime64[ns]
# english                 99632 non-null int64
# platforms               99632 non-null object
# required_age            99632 non-null int64
# categories              99632 non-null object
# genres                  99632 non-null object
# steamspy_tags           99632 non-null object
# achievements            99632 non-null int64
# positive_ratings        99632 non-null int64
# negative_ratings        99632 non-null int64
# average_playtime        99632 non-null int64
# average_forever         99632 non-null object
# median_playtime         99632 non-null int64
# median_forever          99632 non-null object
# owners                  99632 non-null object
# detailed_description    99632 non-null object
# about_the_game          99632 non-null object
# short_description       99632 non-null object
# price                   99632 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(19)
# memory usage: 23.6+ MB

# %%
# converting id to an interger
steam['id'].astype(str).astype(int)
# Out:
# 0        151603712
# 1        151603712
# 2        187131847
# 3        187131847
# 4        176410694
#            ...
# 99627     58345543
# 99628     60859695
# 99629     60859695
# 99630    147602462
# 99631    147602462
# Name: id, Length: 99632, dtype: int32

# %%
# converting appid to an integer
steam['appid'] = steam['appid'].astype(str).astype('int64')

# %%
# checking if the changes were made
steam.dtypes
# Out:
# id                               int64
# appid                            int64
# name                            object
# purchase                        object
# hours_of_play                  float64
# developer                       object
# publisher                       object
# score_rank                      object
# positive                        object
# negative                        object
# userscore                       object
# release_date            datetime64[ns]
# english                          int64
# platforms                       object
# required_age                     int64
# categories                      object
# genres                          object
# steamspy_tags                   object
# achievements                     int64
# positive_ratings                 int64
# negative_ratings                 int64
# average_playtime                 int64
# average_forever                 object
# median_playtime                  int64
# median_forever                  object
# owners                          object
# detailed_description            object
# about_the_game                  object
# short_description               object
# price                          float64
# dtype: object

# %%
# checking the unique game names in the column 'name'
steam.name.unique()
# Out:
# array(['Dota 2', 'Team Fortress 2', 'Unturned', ..., 'Requiem', 'Kuros',
#        'Mystery of Neuschwanstein'], dtype=object)

# %%
# checking the unique game names in the column 'score_rank'
steam.score_rank.unique()
# Out:
# array([''], dtype=object)

# %%
# checking the unique game names in the column 'userscore'
steam.userscore.unique()
# Out:
# array([0], dtype=object)

# %% [markdown]
# As both 'score_rank' and 'userscore' contain variables that are empty or contain zeros, these columns will be deleted as they are not usefull. In addition to that 'average_forever', 'median_forever', 'postivie_ratings' and 'negative_ratings' will also be removed from the data frame.

# %%
# deleting the unessesary columns
del steam['userscore']
del steam['score_rank']
del steam['average_forever']
del steam['median_forever']
del steam['positive_ratings']
del steam['negative_ratings']

# %%
# creating a new column to show the percentage of positive ratings of games
# adding the positive and negative columns
steam['rank'] = steam['positive'] + steam['negative']

# %%
# dividing positive column by the rank column
steam['rank'] = steam['positive']/steam['rank']

# %%
# multiplying rank by 100 to get percentage
steam['rank'] = steam['rank'] * 100

# %% [markdown]
# # Final data frame

# %% [markdown]
# <b>Variables:</b>
# <li><b>'id':</b> unique ids of users
# <li><b>'appid':</b> unique ids of each game
# <li><b>'name':</b> name of the game
# <li><b>'purchase':</b> purchased or played
# <li><b>'hours_of_play':</b> hours of play, value is 1.0 if purchased
# <li><b>'developer':</b> developer of the game
# <li><b>'publisher':</b> publisher of the game
# <li><b>'positive':</b> postive ratings of the game
# <li><b>'negative':</b> negative ratings of the game
# <li><b>'release_date':</b> game release date
# <li><b>'english':</b> returns if the game is english or not
# <li><b>'platforms':</b> compatible platforms
# <li><b>'required_age':</b> minimum age requirements of game
# <li><b>'categories':</b> game categories
# <li><b>'genres':</b> game genres
# <li><b>'steamspy_tags':</b> tags of game
# <li><b>'achievements':</b> game achievements completed
# <li><b>'average_playtime':</b> average playtime
# <li><b>'median_playtime':</b> median playtime
# <li><b>'owners':</b> amount of people who purpchased the game
# <li><b>'detailed_description':</b> detailed description of the game
# <li><b>'about_the_game':</b> information about the game
# <li><b>'short_description':</b> short description of the game
# <li><b>'price':</b> price
# <li><b>'rank':</b> percentage of positive ratings

# %%
# checking the final data frame
steam.head()
# Out:
#           id  appid    name  purchase  hours_of_play developer publisher positive negative  \
# 0  151603712    570  Dota 2  purchase            0.0     Valve     Valve  1097301   194384
# 1  151603712    570  Dota 2      play            0.5     Valve     Valve  1097301   194384
# 2  187131847    570  Dota 2  purchase            0.0     Valve     Valve  1097301   194384
# 3  187131847    570  Dota 2      play            2.3     Valve     Valve  1097301   194384
# 4  176410694    570  Dota 2  purchase            0.0     Valve     Valve  1097301   194384
#
#   release_date  english          platforms  required_age  \
# 0   2013-07-09        1  windows;mac;linux             0
# 1   2013-07-09        1  windows;mac;linux             0
# 2   2013-07-09        1  windows;mac;linux             0
# 3   2013-07-09        1  windows;mac;linux             0
# 4   2013-07-09        1  windows;mac;linux             0
#
#                                           categories                        genres  \
# 0  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 1  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 2  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 3  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
# 4  Multi-player;Co-op;Steam Trading Cards;Steam W...  Action;Free to Play;Strategy
#
#                 steamspy_tags  achievements  average_playtime  median_playtime  \
# 0  Free to Play;MOBA;Strategy             0             23944              801
# 1  Free to Play;MOBA;Strategy             0             23944              801
# 2  Free to Play;MOBA;Strategy             0             23944              801
# 3  Free to Play;MOBA;Strategy             0             23944              801
# 4  Free to Play;MOBA;Strategy             0             23944              801
#
#                 owners                               detailed_description  \
# 0  100000000-200000000  <strong>The most-played game on Steam.</strong...
# 1  100000000-200000000  <strong>The most-played game on Steam.</strong...
# 2  100000000-200000000  <strong>The most-played game on Steam.</strong...
# 3  100000000-200000000  <strong>The most-played game on Steam.</strong...
# 4  100000000-200000000  <strong>The most-played game on Steam.</strong...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  <strong>The most-played game on Steam.</strong...
# 2  <strong>The most-played game on Steam.</strong...
# 3  <strong>The most-played game on Steam.</strong...
# 4  <strong>The most-played game on Steam.</strong...
#
#                                    short_description  price     rank
# 0  Every day, millions of players worldwide enter...    0.0  84.9511
# 1  Every day, millions of players worldwide enter...    0.0  84.9511
# 2  Every day, millions of players worldwide enter...    0.0  84.9511
# 3  Every day, millions of players worldwide enter...    0.0  84.9511
# 4  Every day, millions of players worldwide enter...    0.0  84.9511

# %% [markdown]
# # Saving the final cleaned data frame to a csv file

# %%
steam.to_csv('steam_rs.csv', index=False)
